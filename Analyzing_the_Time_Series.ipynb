# %% [markdown]
# # Analyzing the Time Series

# %%
from statsmodels.tsa.ar_model import AR

# %%
from random import random

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import csv
import pandas as pd
import numpy as np
import pickle

# %%
WDI_path="/home/hendra/Datasets/WDI_Indonesia/"

# %% [markdown]
# ### Constructing a Dictionary for Converting Indicator names into Codes

# %%
Tbl_konversi_indikator_names = pd.read_csv(WDI_path+"WDI_Tabel_Konversi_Indikator.csv", sep=";")

# %%
keys = list(Tbl_konversi_indikator_names["Series Name"])

# %%
values = list(Tbl_konversi_indikator_names["Series Code"])

# %%
the_dictionary = dict(zip(keys, values))

# %%
the_dictionary
# Out:
# {'Agricultural machinery, tractors': 'AG.AGR.TRAC.NO',
#  'Fertilizer consumption (% of fertilizer production)': 'AG.CON.FERT.PT.ZS',
#  'Fertilizer consumption (kilograms per hectare of arable land)': 'AG.CON.FERT.ZS',
#  'Agricultural land (sq. km)': 'AG.LND.AGRI.K2',
#  'Agricultural land (% of land area)': 'AG.LND.AGRI.ZS',
#  'Arable land (hectares)': 'AG.LND.ARBL.HA',
#  'Arable land (hectares per person)': 'AG.LND.ARBL.HA.PC',
#  'Arable land (% of land area)': 'AG.LND.ARBL.ZS',
#  'Land under cereal production (hectares)': 'AG.LND.CREL.HA',
#  'Permanent cropland (% of land area)': 'AG.LND.CROP.ZS',
#  'Rural land area where elevation is below 5 meters (sq. km)': 'AG.LND.EL5M.RU.K2',
#  'Rural land area where elevation is below 5 meters (% of total land area)': 'AG.LND.EL5M.RU.ZS',
#  'Urban land area where elevation is below 5 meters (sq. km)': 'AG.LND.EL5M.UR.K2',
#  'Urban land area where elevation is below 5 meters (% of total land area)': 'AG.LND.EL5M.UR.ZS',
#  'Land area where elevation is below 5 meters (% of total land area)': 'AG.LND.EL5M.ZS',
#  'Forest area (sq. km)': 'AG.LND.FRST.K2',
#  'Forest area (% of land area)': 'AG.LND.FRST.ZS',
#  'Agricultural irrigated land (% of total agricultural land)': 'AG.LND.IRIG.AG.ZS',
#  'Average precipitation in depth (mm per year)': 'AG.LND.PRCP.MM',
#  'Land area (sq. km)': 'AG.LND.TOTL.K2',
#  'Rural land area (sq. km)': 'AG.LND.TOTL.RU.K2',
#  'Urban land area (sq. km)': 'AG.LND.TOTL.UR.K2',
#  'Agricultural machinery, tractors per 100 sq. km of arable land': 'AG.LND.TRAC.ZS',
#  'Cereal production (metric tons)': 'AG.PRD.CREL.MT',
#  'Crop production index (2004-2006 = 100)': 'AG.PRD.CROP.XD',
#  'Food production index (2004-2006 = 100)': 'AG.PRD.FOOD.XD',
#  'Livestock production index (2004-2006 = 100)': 'AG.PRD.LVSK.XD',
#  'Surface area (sq. km)': 'AG.SRF.TOTL.K2',
#  'Cereal yield (kg per hectare)': 'AG.YLD.CREL.KG',
#  'Trade in services (% of GDP)': 'BG.GSR.NFSV.GD.ZS',
#  'Communications, computer, etc. (% of service imports, BoP)': 'BM.GSR.CMCP.ZS',
#  'Primary income payments (BoP, current US$)': 'BM.GSR.FCTY.CD',
#  'Imports of goods and services (BoP, current US$)': 'BM.GSR.GNFS.CD',
#  'Insurance and financial services (% of service imports, BoP)': 'BM.GSR.INSF.ZS',
#  'Goods imports (BoP, current US$)': 'BM.GSR.MRCH.CD',
#  'Service imports (BoP, current US$)': 'BM.GSR.NFSV.CD',
#  'Charges for the use of intellectual property, payments (BoP, current US$)': 'BM.GSR.ROYL.CD',
#  'Imports of goods, services and primary income (BoP, current US$)': 'BM.GSR.TOTL.CD',
#  'Transport services (% of service imports, BoP)': 'BM.GSR.TRAN.ZS',
#  'Travel services (% of service imports, BoP)': 'BM.GSR.TRVL.ZS',
#  'Foreign direct investment, net outflows (BoP, current US$)': 'BM.KLT.DINV.CD.WD',
#  'Foreign direct investment, net outflows (% of GDP)': 'BM.KLT.DINV.WD.GD.ZS',
#  'Secondary income, other sectors, payments (BoP, current US$)': 'BM.TRF.PRVT.CD',
#  'Personal remittances, paid (current US$)': 'BM.TRF.PWKR.CD.DT',
#  'Current account balance (BoP, current US$)': 'BN.CAB.XOKA.CD',
#  'Current account balance (% of GDP)': 'BN.CAB.XOKA.GD.ZS',
#  'Net financial account (BoP, current US$)': 'BN.FIN.TOTL.CD',
#  'Net primary income (BoP, current US$)': 'BN.GSR.FCTY.CD',
#  'Net trade in goods and services (BoP, current US$)': 'BN.GSR.GNFS.CD',
#  'Net trade in goods (BoP, current US$)': 'BN.GSR.MRCH.CD',
#  'Net errors and omissions (BoP, current US$)': 'BN.KAC.EOMS.CD',
#  'Foreign direct investment, net (BoP, current US$)': 'BN.KLT.DINV.CD',
#  'Portfolio Investment, net (BoP, current US$)': 'BN.KLT.PTXL.CD',
#  'Reserves and related items (BoP, current US$)': 'BN.RES.INCL.CD',
#  'Net secondary income (BoP, current US$)': 'BN.TRF.CURR.CD',
#  'Net capital account (BoP, current US$)': 'BN.TRF.KOGT.CD',
#  'Grants, excluding technical cooperation (BoP, current US$)': 'BX.GRT.EXTA.CD.WD',
#  'Technical cooperation grants (BoP, current US$)': 'BX.GRT.TECH.CD.WD',
#  'ICT service exports (BoP, current US$)': 'BX.GSR.CCIS.CD',
#  'ICT service exports (% of service exports, BoP)': 'BX.GSR.CCIS.ZS',
#  'Communications, computer, etc. (% of service exports, BoP)': 'BX.GSR.CMCP.ZS',
#  'Primary income receipts (BoP, current US$)': 'BX.GSR.FCTY.CD',
#  'Exports of goods and services (BoP, current US$)': 'BX.GSR.GNFS.CD',
#  'Insurance and financial services (% of service exports, BoP)': 'BX.GSR.INSF.ZS',
#  'Goods exports (BoP, current US$)': 'BX.GSR.MRCH.CD',
#  'Service exports (BoP, current US$)': 'BX.GSR.NFSV.CD',
#  'Charges for the use of intellectual property, receipts (BoP, current US$)': 'BX.GSR.ROYL.CD',
#  'Exports of goods, services and primary income (BoP, current US$)': 'BX.GSR.TOTL.CD',
#  'Transport services (% of service exports, BoP)': 'BX.GSR.TRAN.ZS',
#  'Travel services (% of service exports, BoP)': 'BX.GSR.TRVL.ZS',
#  'Foreign direct investment, net inflows (BoP, current US$)': 'BX.KLT.DINV.CD.WD',
#  'Foreign direct investment, net inflows (% of GDP)': 'BX.KLT.DINV.WD.GD.ZS',
#  'Primary income on FDI, payments (current US$)': 'BX.KLT.DREM.CD.DT',
#  'Portfolio equity, net inflows (BoP, current US$)': 'BX.PEF.TOTL.CD.WD',
#  'Secondary income receipts (BoP, current US$)': 'BX.TRF.CURR.CD',
#  'Personal transfers, receipts (BoP, current US$)': 'BX.TRF.PWKR.CD',
#  'Personal remittances, received (current US$)': 'BX.TRF.PWKR.CD.DT',
#  'Personal remittances, received (% of GDP)': 'BX.TRF.PWKR.DT.GD.ZS',
#  'S&P Global Equity Indices (annual % change)': 'CM.MKT.INDX.ZG',
#  'Market capitalization of listed domestic companies (current US$)': 'CM.MKT.LCAP.CD',
#  'Market capitalization of listed domestic companies (% of GDP)': 'CM.MKT.LCAP.GD.ZS',
#  'Listed domestic companies, total': 'CM.MKT.LDOM.NO',
#  'Stocks traded, total value (current US$)': 'CM.MKT.TRAD.CD',
#  'Stocks traded, total value (% of GDP)': 'CM.MKT.TRAD.GD.ZS',
#  'Stocks traded, turnover ratio of domestic shares (%)': 'CM.MKT.TRNR',
#  'Net bilateral aid flows from DAC donors, Australia (current US$)': 'DC.DAC.AUSL.CD',
#  'Net bilateral aid flows from DAC donors, Austria (current US$)': 'DC.DAC.AUTL.CD',
#  'Net bilateral aid flows from DAC donors, Belgium (current US$)': 'DC.DAC.BELL.CD',
#  'Net bilateral aid flows from DAC donors, Canada (current US$)': 'DC.DAC.CANL.CD',
#  'Net bilateral aid flows from DAC donors, European Union institutions (current US$)': 'DC.DAC.CECL.CD',
#  'Net bilateral aid flows from DAC donors, Switzerland (current US$)': 'DC.DAC.CHEL.CD',
#  'Net bilateral aid flows from DAC donors, Czech Republic (current US$)': 'DC.DAC.CZEL.CD',
#  'Net bilateral aid flows from DAC donors, Germany (current US$)': 'DC.DAC.DEUL.CD',
#  'Net bilateral aid flows from DAC donors, Denmark (current US$)': 'DC.DAC.DNKL.CD',
#  'Net bilateral aid flows from DAC donors, Spain (current US$)': 'DC.DAC.ESPL.CD',
#  'Net bilateral aid flows from DAC donors, Finland (current US$)': 'DC.DAC.FINL.CD',
#  'Net bilateral aid flows from DAC donors, France (current US$)': 'DC.DAC.FRAL.CD',
#  'Net bilateral aid flows from DAC donors, United Kingdom (current US$)': 'DC.DAC.GBRL.CD',
#  'Net bilateral aid flows from DAC donors, Greece (current US$)': 'DC.DAC.GRCL.CD',
#  'Net bilateral aid flows from DAC donors, Ireland (current US$)': 'DC.DAC.IRLL.CD',
#  'Net bilateral aid flows from DAC donors, Iceland (current US$)': 'DC.DAC.ISLL.CD',
#  'Net bilateral aid flows from DAC donors, Italy (current US$)': 'DC.DAC.ITAL.CD',
#  'Net bilateral aid flows from DAC donors, Japan (current US$)': 'DC.DAC.JPNL.CD',
#  'Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)': 'DC.DAC.KORL.CD',
#  'Net bilateral aid flows from DAC donors, Luxembourg (current US$)': 'DC.DAC.LUXL.CD',
#  'Net bilateral aid flows from DAC donors, Netherlands (current US$)': 'DC.DAC.NLDL.CD',
#  'Net bilateral aid flows from DAC donors, Norway (current US$)': 'DC.DAC.NORL.CD',
#  'Net bilateral aid flows from DAC donors, New Zealand (current US$)': 'DC.DAC.NZLL.CD',
#  'Net bilateral aid flows from DAC donors, Poland (current US$)': 'DC.DAC.POLL.CD',
#  'Net bilateral aid flows from DAC donors, Portugal (current US$)': 'DC.DAC.PRTL.CD',
#  'Net bilateral aid flows from DAC donors, Slovak Republic (current US$)': 'DC.DAC.SVKL.CD',
#  'Net bilateral aid flows from DAC donors, Slovenia (current US$)': 'DC.DAC.SVNL.CD',
#  'Net bilateral aid flows from DAC donors, Sweden (current US$)': 'DC.DAC.SWEL.CD',
#  'Net bilateral aid flows from DAC donors, Total (current US$)': 'DC.DAC.TOTL.CD',
#  'Net bilateral aid flows from DAC donors, United States (current US$)': 'DC.DAC.USAL.CD',
#  'PPG, bilateral (AMT, current US$)': 'DT.AMT.BLAT.CD',
#  'PPG, bilateral concessional (AMT, current US$)': 'DT.AMT.BLTC.CD',
#  'IMF repurchases (AMT, current US$)': 'DT.AMT.DIMF.CD',
#  'Principal repayments on external debt, long-term + IMF (AMT, current US$)': 'DT.AMT.DLTF.CD',
#  'Principal repayments on external debt, long-term (AMT, current US$)': 'DT.AMT.DLXF.CD',
#  'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)': 'DT.AMT.DPNG.CD',
#  'Principal repayments on external debt, public and publicly guaranteed (PPG) (AMT, current US$)': 'DT.AMT.DPPG.CD',
#  'PPG, IBRD (AMT, current US$)': 'DT.AMT.MIBR.CD',
#  'PPG, IDA (AMT, current US$)': 'DT.AMT.MIDA.CD',
#  'PPG, multilateral (AMT, current US$)': 'DT.AMT.MLAT.CD',
#  'PPG, multilateral concessional (AMT, current US$)': 'DT.AMT.MLTC.CD',
#  'PPG, official creditors (AMT, current US$)': 'DT.AMT.OFFT.CD',
#  'PPG, bonds (AMT, current US$)': 'DT.AMT.PBND.CD',
#  'PPG, commercial banks (AMT, current US$)': 'DT.AMT.PCBK.CD',
#  'PNG, bonds (AMT, current US$)': 'DT.AMT.PNGB.CD',
#  'PNG, commercial banks and other creditors (AMT, current US$)': 'DT.AMT.PNGC.CD',
#  'PPG, other private creditors (AMT, current US$)': 'DT.AMT.PROP.CD',
#  'PPG, private creditors (AMT, current US$)': 'DT.AMT.PRVT.CD',
#  'Principal arrears, long-term DOD (US$)': 'DT.AXA.DPPG.CD',
#  'Principal arrears, official creditors (current US$)': 'DT.AXA.OFFT.CD',
#  'Principal arrears, private creditors (current US$)': 'DT.AXA.PRVT.CD',
#  'Principal forgiven (current US$)': 'DT.AXF.DPPG.CD',
#  'Principal rescheduled (current US$)': 'DT.AXR.DPPG.CD',
#  'Principal rescheduled, official (current US$)': 'DT.AXR.OFFT.CD',
#  'Principal rescheduled, private (current US$)': 'DT.AXR.PRVT.CD',
#  'Commitments, public and publicly guaranteed (COM, current US$)': 'DT.COM.DPPG.CD',
#  'Commitments, IBRD (COM, current US$)': 'DT.COM.MIBR.CD',
#  'Commitments, IDA (COM, current US$)': 'DT.COM.MIDA.CD',
#  'Commitments, official creditors (COM, current US$)': 'DT.COM.OFFT.CD',
#  'Commitments, private creditors (COM, current US$)': 'DT.COM.PRVT.CD',
#  'Currency composition of PPG debt, Deutsche mark (%)': 'DT.CUR.DMAK.ZS',
#  'Currency composition of PPG debt, Euro (%)': 'DT.CUR.EURO.ZS',
#  'Currency composition of PPG debt, French franc (%)': 'DT.CUR.FFRC.ZS',
#  'Currency composition of PPG debt, Japanese yen (%)': 'DT.CUR.JYEN.ZS',
#  'Currency composition of PPG debt, Multiple currencies (%)': 'DT.CUR.MULC.ZS',
#  'Currency composition of PPG debt, all other currencies (%)': 'DT.CUR.OTHC.ZS',
#  'Currency composition of PPG debt, SDR (%)': 'DT.CUR.SDRW.ZS',
#  'Currency composition of PPG debt, Swiss franc (%)': 'DT.CUR.SWFR.ZS',
#  'Currency composition of PPG debt, Pound sterling (%)': 'DT.CUR.UKPS.ZS',
#  'Currency composition of PPG debt, U.S. dollars (%)': 'DT.CUR.USDL.ZS',
#  'Debt forgiveness or reduction (current US$)': 'DT.DFR.DPPG.CD',
#  'PPG, bilateral (DIS, current US$)': 'DT.DIS.BLAT.CD',
#  'PPG, bilateral concessional (DIS, current US$)': 'DT.DIS.BLTC.CD',
#  'IMF purchases (DIS, current US$)': 'DT.DIS.DIMF.CD',
#  'Disbursements on external debt, long-term + IMF (DIS, current US$)': 'DT.DIS.DLTF.CD',
#  'Disbursements on external debt, long-term (DIS, current US$)': 'DT.DIS.DLXF.CD',
#  'Disbursements on external debt, private nonguaranteed (PNG) (DIS, current US$)': 'DT.DIS.DPNG.CD',
#  'Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)': 'DT.DIS.DPPG.CD',
#  'IDA grants (current US$)': 'DT.DIS.IDAG.CD',
#  'PPG, IBRD (DIS, current US$)': 'DT.DIS.MIBR.CD',
#  'PPG, IDA (DIS, current US$)': 'DT.DIS.MIDA.CD',
#  'PPG, multilateral (DIS, current US$)': 'DT.DIS.MLAT.CD',
#  'PPG, multilateral concessional (DIS, current US$)': 'DT.DIS.MLTC.CD',
#  'PPG, official creditors (DIS, current US$)': 'DT.DIS.OFFT.CD',
#  'PPG, bonds (DIS, current US$)': 'DT.DIS.PBND.CD',
#  'PPG, commercial banks (DIS, current US$)': 'DT.DIS.PCBK.CD',
#  'PNG, bonds (DIS, current US$)': 'DT.DIS.PNGB.CD',
#  'PNG, commercial banks and other creditors (DIS, current US$)': 'DT.DIS.PNGC.CD',
#  'PPG, other private creditors (DIS, current US$)': 'DT.DIS.PROP.CD',
#  'PPG, private creditors (DIS, current US$)': 'DT.DIS.PRVT.CD',
#  'External debt stocks, concessional (DOD, current US$)': 'DT.DOD.ALLC.CD',
#  'Concessional debt (% of total external debt)': 'DT.DOD.ALLC.ZS',
#  'PPG, bilateral (DOD, current US$)': 'DT.DOD.BLAT.CD',
#  'PPG, bilateral concessional (DOD, current US$)': 'DT.DOD.BLTC.CD',
#  'External debt stocks, total (DOD, current US$)': 'DT.DOD.DECT.CD',
#  'Total change in external debt stocks (current US$)': 'DT.DOD.DECT.CD.CG',
#  'External debt stocks (% of exports of goods, services and primary income)': 'DT.DOD.DECT.EX.ZS',
#  'External debt stocks (% of GNI)': 'DT.DOD.DECT.GN.ZS',
#  'Use of IMF credit (DOD, current US$)': 'DT.DOD.DIMF.CD',
#  'External debt stocks, long-term (DOD, current US$)': 'DT.DOD.DLXF.CD',
#  'External debt stocks, private nonguaranteed (PNG) (DOD, current US$)': 'DT.DOD.DPNG.CD',
#  'External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)': 'DT.DOD.DPPG.CD',
#  'External debt stocks, short-term (DOD, current US$)': 'DT.DOD.DSTC.CD',
#  'Short-term debt (% of total reserves)': 'DT.DOD.DSTC.IR.ZS',
#  'Short-term debt (% of exports of goods, services and primary income)': 'DT.DOD.DSTC.XP.ZS',
#  'Short-term debt (% of total external debt)': 'DT.DOD.DSTC.ZS',
#  'Debt forgiveness grants (current US$)': 'DT.DOD.MDRI.CD',
#  'PPG, IBRD (DOD, current US$)': 'DT.DOD.MIBR.CD',
#  'PPG, IDA (DOD, current US$)': 'DT.DOD.MIDA.CD',
#  'PPG, multilateral (DOD, current US$)': 'DT.DOD.MLAT.CD',
#  'Multilateral debt (% of total external debt)': 'DT.DOD.MLAT.ZS',
#  'PPG, multilateral concessional (DOD, current US$)': 'DT.DOD.MLTC.CD',
#  'IBRD loans and IDA credits (DOD, current US$)': 'DT.DOD.MWBG.CD',
#  'PPG, official creditors (DOD, current US$)': 'DT.DOD.OFFT.CD',
#  'PPG, bonds (DOD, current US$)': 'DT.DOD.PBND.CD',
#  'PPG, commercial banks (DOD, current US$)': 'DT.DOD.PCBK.CD',
#  'PNG, bonds (DOD, current US$)': 'DT.DOD.PNGB.CD',
#  'PNG, commercial banks and other creditors (DOD, current US$)': 'DT.DOD.PNGC.CD',
#  'PPG, other private creditors (DOD, current US$)': 'DT.DOD.PROP.CD',
#  'External debt stocks, long-term private sector (DOD, current US$)': 'DT.DOD.PRVS.CD',
#  'PPG, private creditors (DOD, current US$)': 'DT.DOD.PRVT.CD',
#  'External debt stocks, long-term public sector (DOD, current US$)': 'DT.DOD.PUBS.CD',
#  'Present value of external debt (current US$)': 'DT.DOD.PVLX.CD',
#  'Present value of external debt (% of exports of goods, services and primary income)': 'DT.DOD.PVLX.EX.ZS',
#  'Present value of external debt (% of GNI)': 'DT.DOD.PVLX.GN.ZS',
#  'Residual, debt stock-flow reconciliation (current US$)': 'DT.DOD.RSDL.CD',
#  'External debt stocks, variable rate (DOD, current US$)': 'DT.DOD.VTOT.CD',
#  'Debt buyback (current US$)': 'DT.DSB.DPPG.CD',
#  'Debt stock reduction (current US$)': 'DT.DSF.DPPG.CD',
#  'Debt stock rescheduled (current US$)': 'DT.DXR.DPPG.CD',
#  'Average grace period on new external debt commitments (years)': 'DT.GPA.DPPG',
#  'Average grace period on new external debt commitments, official (years)': 'DT.GPA.OFFT',
#  'Average grace period on new external debt commitments, private (years)': 'DT.GPA.PRVT',
#  'Average grant element on new external debt commitments (%)': 'DT.GRE.DPPG',
#  'Average grant element on new external debt commitments, official (%)': 'DT.GRE.OFFT',
#  'Average grant element on new external debt commitments, private (%)': 'DT.GRE.PRVT',
#  'Average interest on new external debt commitments (%)': 'DT.INR.DPPG',
#  'Average interest on new external debt commitments, official (%)': 'DT.INR.OFFT',
#  'Average interest on new external debt commitments, private (%)': 'DT.INR.PRVT',
#  'PPG, bilateral (INT, current US$)': 'DT.INT.BLAT.CD',
#  'PPG, bilateral concessional (INT, current US$)': 'DT.INT.BLTC.CD',
#  'Interest payments on external debt, total (INT, current US$)': 'DT.INT.DECT.CD',
#  'Interest payments on external debt (% of exports of goods, services and primary income)': 'DT.INT.DECT.EX.ZS',
#  'Interest payments on external debt (% of GNI)': 'DT.INT.DECT.GN.ZS',
#  'IMF charges (INT, current US$)': 'DT.INT.DIMF.CD',
#  'Interest payments on external debt, long-term (INT, current US$)': 'DT.INT.DLXF.CD',
#  'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)': 'DT.INT.DPNG.CD',
#  'Interest payments on external debt, public and publicly guaranteed (PPG) (INT, current US$)': 'DT.INT.DPPG.CD',
#  'Interest payments on external debt, short-term (INT, current US$)': 'DT.INT.DSTC.CD',
#  'PPG, IBRD (INT, current US$)': 'DT.INT.MIBR.CD',
#  'PPG, IDA (INT, current US$)': 'DT.INT.MIDA.CD',
#  'PPG, multilateral (INT, current US$)': 'DT.INT.MLAT.CD',
#  'PPG, multilateral concessional (INT, current US$)': 'DT.INT.MLTC.CD',
#  'PPG, official creditors (INT, current US$)': 'DT.INT.OFFT.CD',
#  'PPG, bonds (INT, current US$)': 'DT.INT.PBND.CD',
#  'PPG, commercial banks (INT, current US$)': 'DT.INT.PCBK.CD',
#  'PNG, bonds (INT, current US$)': 'DT.INT.PNGB.CD',
#  'PNG, commercial banks and other creditors (INT, current US$)': 'DT.INT.PNGC.CD',
#  'PPG, other private creditors (INT, current US$)': 'DT.INT.PROP.CD',
#  'PPG, private creditors (INT, current US$)': 'DT.INT.PRVT.CD',
#  'Interest arrears, long-term DOD (US$)': 'DT.IXA.DPPG.CD',
#  'Net change in interest arrears (current US$)': 'DT.IXA.DPPG.CD.CG',
#  'Interest arrears, official creditors (current US$)': 'DT.IXA.OFFT.CD',
#  'Interest arrears, private creditors (current US$)': 'DT.IXA.PRVT.CD',
#  'Interest forgiven (current US$)': 'DT.IXF.DPPG.CD',
#  'Interest rescheduled (capitalized) (current US$)': 'DT.IXR.DPPG.CD',
#  'Interest rescheduled, official (current US$)': 'DT.IXR.OFFT.CD',
#  'Interest rescheduled, private (current US$)': 'DT.IXR.PRVT.CD',
#  'Average maturity on new external debt commitments (years)': 'DT.MAT.DPPG',
#  'Average maturity on new external debt commitments, official (years)': 'DT.MAT.OFFT',
#  'Average maturity on new external debt commitments, private (years)': 'DT.MAT.PRVT',
#  'Net financial flows, bilateral (NFL, current US$)': 'DT.NFL.BLAT.CD',
#  'PPG, bilateral concessional (NFL, current US$)': 'DT.NFL.BLTC.CD',
#  'Portfolio investment, bonds (PPG + PNG) (NFL, current US$)': 'DT.NFL.BOND.CD',
#  'Net flows on external debt, total (NFL, current US$)': 'DT.NFL.DECT.CD',
#  'Net flows on external debt, long-term (NFL, current US$)': 'DT.NFL.DLXF.CD',
#  'Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)': 'DT.NFL.DPNG.CD',
#  'Net flows on external debt, public and publicly guaranteed (PPG) (NFL, current US$)': 'DT.NFL.DPPG.CD',
#  'Net flows on external debt, short-term (NFL, current US$)': 'DT.NFL.DSTC.CD',
#  'Net official flows from UN agencies, FAO (current US$)': 'DT.NFL.FAOG.CD',
#  'Net official flows from UN agencies, IAEA (current US$)': 'DT.NFL.IAEA.CD',
#  'Net official flows from UN agencies, IFAD (current US$)': 'DT.NFL.IFAD.CD',
#  'Net official flows from UN agencies, ILO (current US$)': 'DT.NFL.ILOG.CD',
#  'Net financial flows, IMF concessional (NFL, current US$)': 'DT.NFL.IMFC.CD',
#  'Net financial flows, IMF nonconcessional (NFL, current US$)': 'DT.NFL.IMFN.CD',
#  'Net financial flows, IBRD (NFL, current US$)': 'DT.NFL.MIBR.CD',
#  'Net financial flows, IDA (NFL, current US$)': 'DT.NFL.MIDA.CD',
#  'Net financial flows, multilateral (NFL, current US$)': 'DT.NFL.MLAT.CD',
#  'PPG, multilateral concessional (NFL, current US$)': 'DT.NFL.MLTC.CD',
#  'Net financial flows, others (NFL, current US$)': 'DT.NFL.MOTH.CD',
#  'EBRD, private nonguaranteed (NFL, current US$)': 'DT.NFL.NEBR.CD',
#  'IFC, private nonguaranteed (NFL, current US$)': 'DT.NFL.NIFC.CD',
#  'PPG, official creditors (NFL, current US$)': 'DT.NFL.OFFT.CD',
#  'PPG, bonds (NFL, current US$)': 'DT.NFL.PBND.CD',
#  'PPG, commercial banks (NFL, current US$)': 'DT.NFL.PCBK.CD',
#  'Commercial banks and other lending (PPG + PNG) (NFL, current US$)': 'DT.NFL.PCBO.CD',
#  'PNG, bonds (NFL, current US$)': 'DT.NFL.PNGB.CD',
#  'PNG, commercial banks and other creditors (NFL, current US$)': 'DT.NFL.PNGC.CD',
#  'PPG, other private creditors (NFL, current US$)': 'DT.NFL.PROP.CD',
#  'PPG, private creditors (NFL, current US$)': 'DT.NFL.PRVT.CD',
#  'Net financial flows, RDB concessional (NFL, current US$)': 'DT.NFL.RDBC.CD',
#  'Net financial flows, RDB nonconcessional (NFL, current US$)': 'DT.NFL.RDBN.CD',
#  'Net official flows from UN agencies, UNAIDS (current US$)': 'DT.NFL.UNAI.CD',
#  'Net official flows from UN agencies, UNICEF (current US$)': 'DT.NFL.UNCF.CD',
#  'Net official flows from UN agencies, UNHCR (current US$)': 'DT.NFL.UNCR.CD',
#  'Net official flows from UN agencies, UNDP (current US$)': 'DT.NFL.UNDP.CD',
#  'Net official flows from UN agencies, UNECE (current US$)': 'DT.NFL.UNEC.CD',
#  'Net official flows from UN agencies, UNFPA (current US$)': 'DT.NFL.UNFP.CD',
#  'Net official flows from UN agencies, UNPBF (current US$)': 'DT.NFL.UNPB.CD',
#  'Net official flows from UN agencies, UNRWA (current US$)': 'DT.NFL.UNRW.CD',
#  'Net official flows from UN agencies, UNTA (current US$)': 'DT.NFL.UNTA.CD',
#  'Net official flows from UN agencies, WFP (current US$)': 'DT.NFL.WFPG.CD',
#  'Net official flows from UN agencies, WHO (current US$)': 'DT.NFL.WHOL.CD',
#  'PPG, bilateral (NTR, current US$)': 'DT.NTR.BLAT.CD',
#  'PPG, bilateral concessional (NTR, current US$)': 'DT.NTR.BLTC.CD',
#  'Net transfers on external debt, total (NTR, current US$)': 'DT.NTR.DECT.CD',
#  'Net transfers on external debt, long-term (NTR, current US$)': 'DT.NTR.DLXF.CD',
#  'Net transfers on external debt, private nonguaranteed (PNG) (NTR, current US$)': 'DT.NTR.DPNG.CD',
#  'Net transfers on external debt, public and publicly guaranteed (PPG) (NTR, current US$)': 'DT.NTR.DPPG.CD',
#  'PPG, IBRD (NTR, current US$)': 'DT.NTR.MIBR.CD',
#  'PPG, IDA (NTR, current US$)': 'DT.NTR.MIDA.CD',
#  'PPG, multilateral (NTR, current US$)': 'DT.NTR.MLAT.CD',
#  'PPG, multilateral concessional (NTR, current US$)': 'DT.NTR.MLTC.CD',
#  'PPG, official creditors (NTR, current US$)': 'DT.NTR.OFFT.CD',
#  'PPG, bonds (NTR, current US$)': 'DT.NTR.PBND.CD',
#  'PPG, commercial banks (NTR, current US$)': 'DT.NTR.PCBK.CD',
#  'PNG, bonds (NTR, current US$)': 'DT.NTR.PNGB.CD',
#  'PNG, commercial banks and other creditors (NTR, current US$)': 'DT.NTR.PNGC.CD',
#  'PPG, other private creditors (NTR, current US$)': 'DT.NTR.PROP.CD',
#  'PPG, private creditors (NTR, current US$)': 'DT.NTR.PRVT.CD',
#  'Net official development assistance and official aid received (current US$)': 'DT.ODA.ALLD.CD',
#  'Net official development assistance and official aid received (constant 2013 US$)': 'DT.ODA.ALLD.KD',
#  'Net official aid received (current US$)': 'DT.ODA.OATL.CD',
#  'Net official aid received (constant 2014 US$)': 'DT.ODA.OATL.KD',
#  'Net official development assistance received (current US$)': 'DT.ODA.ODAT.CD',
#  'Net ODA received (% of gross capital formation)': 'DT.ODA.ODAT.GI.ZS',
#  'Net ODA received (% of GNI)': 'DT.ODA.ODAT.GN.ZS',
#  'Net official development assistance received (constant 2014 US$)': 'DT.ODA.ODAT.KD',
#  'Net ODA received (% of imports of goods, services and primary income)': 'DT.ODA.ODAT.MP.ZS',
#  'Net ODA received per capita (current US$)': 'DT.ODA.ODAT.PC.ZS',
#  'Net ODA received (% of central government expense)': 'DT.ODA.ODAT.XP.ZS',
#  'PPG, bilateral (TDS, current US$)': 'DT.TDS.BLAT.CD',
#  'PPG, bilateral concessional (TDS, current US$)': 'DT.TDS.BLTC.CD',
#  'Debt service on external debt, total (TDS, current US$)': 'DT.TDS.DECT.CD',
#  'Total debt service (% of exports of goods, services and primary income)': 'DT.TDS.DECT.EX.ZS',
#  'Total debt service (% of GNI)': 'DT.TDS.DECT.GN.ZS',
#  'IMF repurchases and charges (TDS, current US$)': 'DT.TDS.DIMF.CD',
#  'Debt service on external debt, long-term (TDS, current US$)': 'DT.TDS.DLXF.CD',
#  'Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)': 'DT.TDS.DPNG.CD',
#  'Debt service (PPG and IMF only, % of exports of goods, services and primary income)': 'DT.TDS.DPPF.XP.ZS',
#  'Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)': 'DT.TDS.DPPG.CD',
#  'Public and publicly guaranteed debt service (% of GNI)': 'DT.TDS.DPPG.GN.ZS',
#  'Public and publicly guaranteed debt service (% of exports of goods, services and primary income)': 'DT.TDS.DPPG.XP.ZS',
#  'PPG, IBRD (TDS, current US$)': 'DT.TDS.MIBR.CD',
#  'PPG, IDA (TDS, current US$)': 'DT.TDS.MIDA.CD',
#  'Multilateral debt service (TDS, current US$)': 'DT.TDS.MLAT.CD',
#  'Multilateral debt service (% of public and publicly guaranteed debt service)': 'DT.TDS.MLAT.PG.ZS',
#  'PPG, multilateral concessional (TDS, current US$)': 'DT.TDS.MLTC.CD',
#  'PPG, official creditors (TDS, current US$)': 'DT.TDS.OFFT.CD',
#  'PPG, bonds (TDS, current US$)': 'DT.TDS.PBND.CD',
#  'PPG, commercial banks (TDS, current US$)': 'DT.TDS.PCBK.CD',
#  'PNG, bonds (TDS, current US$)': 'DT.TDS.PNGB.CD',
#  'PNG, commercial banks and other creditors (TDS, current US$)': 'DT.TDS.PNGC.CD',
#  'PPG, other private creditors (TDS, current US$)': 'DT.TDS.PROP.CD',
#  'PPG, private creditors (TDS, current US$)': 'DT.TDS.PRVT.CD',
#  'Total amount of debt rescheduled (current US$)': 'DT.TXR.DPPG.CD',
#  'Undisbursed external debt, total (UND, current US$)': 'DT.UND.DPPG.CD',
#  'Undisbursed external debt, official creditors (UND, current US$)': 'DT.UND.OFFT.CD',
#  'Undisbursed external debt, private creditors (UND, current US$)': 'DT.UND.PRVT.CD',
#  'Agriculture value added per worker (constant 2010 US$)': 'EA.PRD.AGRI.KD',
#  'Access to clean fuels and technologies for cooking  (% of population)': 'EG.CFT.ACCS.ZS',
#  'Energy intensity level of primary energy (MJ/$2011 PPP GDP)': 'EG.EGY.PRIM.PP.KD',
#  'Access to electricity, rural (% of rural population)': 'EG.ELC.ACCS.RU.ZS',
#  'Access to electricity, urban (% of urban population)': 'EG.ELC.ACCS.UR.ZS',
#  'Access to electricity (% of population)': 'EG.ELC.ACCS.ZS',
#  'Electricity production from coal sources (% of total)': 'EG.ELC.COAL.ZS',
#  'Electricity production from oil, gas and coal sources (% of total)': 'EG.ELC.FOSL.ZS',
#  'Electricity production from hydroelectric sources (% of total)': 'EG.ELC.HYRO.ZS',
#  'Electric power transmission and distribution losses (% of output)': 'EG.ELC.LOSS.ZS',
#  'Electricity production from natural gas sources (% of total)': 'EG.ELC.NGAS.ZS',
#  'Electricity production from nuclear sources (% of total)': 'EG.ELC.NUCL.ZS',
#  'Electricity production from oil sources (% of total)': 'EG.ELC.PETR.ZS',
#  'Renewable electricity output (% of total electricity output)': 'EG.ELC.RNEW.ZS',
#  'Electricity production from renewable sources, excluding hydroelectric (kWh)': 'EG.ELC.RNWX.KH',
#  'Electricity production from renewable sources, excluding hydroelectric (% of total)': 'EG.ELC.RNWX.ZS',
#  'Renewable energy consumption (% of total final energy consumption)': 'EG.FEC.RNEW.ZS',
#  'GDP per unit of energy use (PPP $ per kg of oil equivalent)': 'EG.GDP.PUSE.KO.PP',
#  'GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)': 'EG.GDP.PUSE.KO.PP.KD',
#  'Energy imports, net (% of energy use)': 'EG.IMP.CONS.ZS',
#  'Alternative and nuclear energy (% of total energy use)': 'EG.USE.COMM.CL.ZS',
#  'Fossil fuel energy consumption (% of total)': 'EG.USE.COMM.FO.ZS',
#  'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)': 'EG.USE.COMM.GD.PP.KD',
#  'Combustible renewables and waste (% of total energy)': 'EG.USE.CRNW.ZS',
#  'Electric power consumption (kWh per capita)': 'EG.USE.ELEC.KH.PC',
#  'Energy use (kg of oil equivalent per capita)': 'EG.USE.PCAP.KG.OE',
#  'CO2 intensity (kg per kg of oil equivalent energy use)': 'EN.ATM.CO2E.EG.ZS',
#  'CO2 emissions from gaseous fuel consumption (kt)': 'EN.ATM.CO2E.GF.KT',
#  'CO2 emissions from gaseous fuel consumption (% of total)': 'EN.ATM.CO2E.GF.ZS',
#  'CO2 emissions (kg per 2010 US$ of GDP)': 'EN.ATM.CO2E.KD.GD',
#  'CO2 emissions (kt)': 'EN.ATM.CO2E.KT',
#  'CO2 emissions from liquid fuel consumption (kt)': 'EN.ATM.CO2E.LF.KT',
#  'CO2 emissions from liquid fuel consumption (% of total)': 'EN.ATM.CO2E.LF.ZS',
#  'CO2 emissions (metric tons per capita)': 'EN.ATM.CO2E.PC',
#  'CO2 emissions (kg per PPP $ of GDP)': 'EN.ATM.CO2E.PP.GD',
#  'CO2 emissions (kg per 2011 PPP $ of GDP)': 'EN.ATM.CO2E.PP.GD.KD',
#  'CO2 emissions from solid fuel consumption (kt)': 'EN.ATM.CO2E.SF.KT',
#  'CO2 emissions from solid fuel consumption (% of total)': 'EN.ATM.CO2E.SF.ZS',
#  'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)': 'EN.ATM.GHGO.KT.CE',
#  'Other greenhouse gas emissions (% change from 1990)': 'EN.ATM.GHGO.ZG',
#  'Total greenhouse gas emissions (kt of CO2 equivalent)': 'EN.ATM.GHGT.KT.CE',
#  'Total greenhouse gas emissions (% change from 1990)': 'EN.ATM.GHGT.ZG',
#  'HFC gas emissions (thousand metric tons of CO2 equivalent)': 'EN.ATM.HFCG.KT.CE',
#  'Agricultural methane emissions (thousand metric tons of CO2 equivalent)': 'EN.ATM.METH.AG.KT.CE',
#  'Agricultural methane emissions (% of total)': 'EN.ATM.METH.AG.ZS',
#  'Methane emissions in energy sector (thousand metric tons of CO2 equivalent)': 'EN.ATM.METH.EG.KT.CE',
#  'Energy related methane emissions (% of total)': 'EN.ATM.METH.EG.ZS',
#  'Methane emissions (kt of CO2 equivalent)': 'EN.ATM.METH.KT.CE',
#  'Methane emissions (% change from 1990)': 'EN.ATM.METH.ZG',
#  'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)': 'EN.ATM.NOXE.AG.KT.CE',
#  'Agricultural nitrous oxide emissions (% of total)': 'EN.ATM.NOXE.AG.ZS',
#  'Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)': 'EN.ATM.NOXE.EG.KT.CE',
#  'Nitrous oxide emissions in energy sector (% of total)': 'EN.ATM.NOXE.EG.ZS',
#  'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)': 'EN.ATM.NOXE.KT.CE',
#  'Nitrous oxide emissions (% change from 1990)': 'EN.ATM.NOXE.ZG',
#  'PFC gas emissions (thousand metric tons of CO2 equivalent)': 'EN.ATM.PFCG.KT.CE',
#  'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)': 'EN.ATM.PM25.MC.M3',
#  'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)': 'EN.ATM.PM25.MC.ZS',
#  'SF6 gas emissions (thousand metric tons of CO2 equivalent)': 'EN.ATM.SF6G.KT.CE',
#  'Bird species, threatened': 'EN.BIR.THRD.NO',
#  'Disaster risk reduction progress score (1-5 scale; 5=best)': 'EN.CLC.DRSK.XQ',
#  'GHG net emissions/removals by LUCF (Mt of CO2 equivalent)': 'EN.CLC.GHGR.MT.CE',
#  'Droughts, floods, extreme temperatures (% of population, average 1990-2009)': 'EN.CLC.MDAT.ZS',
#  'CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)': 'EN.CO2.BLDG.ZS',
#  'CO2 emissions from electricity and heat production, total (% of total fuel combustion)': 'EN.CO2.ETOT.ZS',
#  'CO2 emissions from manufacturing industries and construction (% of total fuel combustion)': 'EN.CO2.MANF.ZS',
#  'CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)': 'EN.CO2.OTHX.ZS',
#  'CO2 emissions from transport (% of total fuel combustion)': 'EN.CO2.TRAN.ZS',
#  'Fish species, threatened': 'EN.FSH.THRD.NO',
#  'Plant species (higher), threatened': 'EN.HPT.THRD.NO',
#  'Mammal species, threatened': 'EN.MAM.THRD.NO',
#  'Population density (people per sq. km of land area)': 'EN.POP.DNST',
#  'Rural population living in areas where elevation is below 5 meters (% of total population)': 'EN.POP.EL5M.RU.ZS',
#  'Urban population living in areas where elevation is below 5 meters (% of total population)': 'EN.POP.EL5M.UR.ZS',
#  'Population living in areas where elevation is below 5 meters (% of total population)': 'EN.POP.EL5M.ZS',
#  'Population living in slums (% of urban population)': 'EN.POP.SLUM.UR.ZS',
#  'Population in largest city': 'EN.URB.LCTY',
#  'Population in the largest city (% of urban population)': 'EN.URB.LCTY.UR.ZS',
#  'Population in urban agglomerations of more than 1 million': 'EN.URB.MCTY',
#  'Population in urban agglomerations of more than 1 million (% of total population)': 'EN.URB.MCTY.TL.ZS',
#  'Pump price for diesel fuel (US$ per liter)': 'EP.PMP.DESL.CD',
#  'Pump price for gasoline (US$ per liter)': 'EP.PMP.SGAS.CD',
#  'Aquaculture production (metric tons)': 'ER.FSH.AQUA.MT',
#  'Capture fisheries production (metric tons)': 'ER.FSH.CAPT.MT',
#  'Total fisheries production (metric tons)': 'ER.FSH.PROD.MT',
#  'Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)': 'ER.GDP.FWTL.M3.KD',
#  'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)': 'ER.H2O.FWAG.ZS',
#  'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)': 'ER.H2O.FWDM.ZS',
#  'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)': 'ER.H2O.FWIN.ZS',
#  'Annual freshwater withdrawals, total (billion cubic meters)': 'ER.H2O.FWTL.K3',
#  'Annual freshwater withdrawals, total (% of internal resources)': 'ER.H2O.FWTL.ZS',
#  'Renewable internal freshwater resources, total (billion cubic meters)': 'ER.H2O.INTR.K3',
#  'Renewable internal freshwater resources per capita (cubic meters)': 'ER.H2O.INTR.PC',
#  'Terrestrial protected areas (% of total land area)': 'ER.LND.PTLD.ZS',
#  'Marine protected areas (% of territorial waters)': 'ER.MRN.PTMR.ZS',
#  'Terrestrial and marine protected areas (% of total territorial area)': 'ER.PTD.TOTL.ZS',
#  'Bank nonperforming loans to total gross loans (%)': 'FB.AST.NPER.ZS',
#  'Automated teller machines (ATMs) (per 100,000 adults)': 'FB.ATM.TOTL.P5',
#  'Bank capital to assets ratio (%)': 'FB.BNK.CAPA.ZS',
#  'Commercial bank branches (per 100,000 adults)': 'FB.CBK.BRCH.P5',
#  'Borrowers from commercial banks (per 1,000 adults)': 'FB.CBK.BRWR.P3',
#  'Depositors with commercial banks (per 1,000 adults)': 'FB.CBK.DPTR.P3',
#  'Point-of-sale terminals (per 100,000 adults)': 'FB.POS.TOTL.P5',
#  'Domestic credit to private sector by banks (% of GDP)': 'FD.AST.PRVT.GD.ZS',
#  'Bank liquid reserves to bank assets ratio (%)': 'FD.RES.LIQU.AS.ZS',
#  'Total reserves (includes gold, current US$)': 'FI.RES.TOTL.CD',
#  'Total reserves (% of total external debt)': 'FI.RES.TOTL.DT.ZS',
#  'Total reserves in months of imports': 'FI.RES.TOTL.MO',
#  'Total reserves minus gold (current US$)': 'FI.RES.XGLD.CD',
#  'Claims on central government (annual growth as % of broad money)': 'FM.AST.CGOV.ZG.M3',
#  'Claims on other sectors of the domestic economy (annual growth as % of broad money)': 'FM.AST.DOMO.ZG.M3',
#  'Net domestic credit (current LCU)': 'FM.AST.DOMS.CN',
#  'Net foreign assets (current LCU)': 'FM.AST.NFRG.CN',
#  'Claims on private sector (annual growth as % of broad money)': 'FM.AST.PRVT.ZG.M3',
#  'Broad money (current LCU)': 'FM.LBL.BMNY.CN',
#  'Broad money (% of GDP)': 'FM.LBL.BMNY.GD.ZS',
#  'Broad money to total reserves ratio': 'FM.LBL.BMNY.IR.ZS',
#  'Broad money growth (annual %)': 'FM.LBL.BMNY.ZG',
#  'Consumer price index (2010 = 100)': 'FP.CPI.TOTL',
#  'Inflation, consumer prices (annual %)': 'FP.CPI.TOTL.ZG',
#  'Wholesale price index (2010 = 100)': 'FP.WPI.TOTL',
#  'Deposit interest rate (%)': 'FR.INR.DPST',
#  'Lending interest rate (%)': 'FR.INR.LEND',
#  'Interest rate spread (lending rate minus deposit rate, %)': 'FR.INR.LNDP',
#  'Real interest rate (%)': 'FR.INR.RINR',
#  'Risk premium on lending (lending rate minus treasury bill rate, %)': 'FR.INR.RISK',
#  'Claims on central government, etc. (% GDP)': 'FS.AST.CGOV.GD.ZS',
#  'Claims on other sectors of the domestic economy (% of GDP)': 'FS.AST.DOMO.GD.ZS',
#  'Domestic credit provided by financial sector (% of GDP)': 'FS.AST.DOMS.GD.ZS',
#  'Domestic credit to private sector (% of GDP)': 'FS.AST.PRVT.GD.ZS',
#  'Research and development expenditure (% of GDP)': 'GB.XPD.RSDV.GD.ZS',
#  'Net acquisition of financial assets (current LCU)': 'GC.AST.TOTL.CN',
#  'Net acquisition of financial assets (% of GDP)': 'GC.AST.TOTL.GD.ZS',
#  'Central government debt, total (current LCU)': 'GC.DOD.TOTL.CN',
#  'Central government debt, total (% of GDP)': 'GC.DOD.TOTL.GD.ZS',
#  'Net incurrence of liabilities, total (current LCU)': 'GC.LBL.TOTL.CN',
#  'Net incurrence of liabilities, total (% of GDP)': 'GC.LBL.TOTL.GD.ZS',
#  'Net investment in nonfinancial assets (current LCU)': 'GC.NFN.TOTL.CN',
#  'Net investment in nonfinancial assets (% of GDP)': 'GC.NFN.TOTL.GD.ZS',
#  'Net lending (+) / net borrowing (-) (current LCU)': 'GC.NLD.TOTL.CN',
#  'Net lending (+) / net borrowing (-) (% of GDP)': 'GC.NLD.TOTL.GD.ZS',
#  'Grants and other revenue (current LCU)': 'GC.REV.GOTR.CN',
#  'Grants and other revenue (% of revenue)': 'GC.REV.GOTR.ZS',
#  'Social contributions (current LCU)': 'GC.REV.SOCL.CN',
#  'Social contributions (% of revenue)': 'GC.REV.SOCL.ZS',
#  'Revenue, excluding grants (current LCU)': 'GC.REV.XGRT.CN',
#  'Revenue, excluding grants (% of GDP)': 'GC.REV.XGRT.GD.ZS',
#  'Taxes on exports (current LCU)': 'GC.TAX.EXPT.CN',
#  'Taxes on exports (% of tax revenue)': 'GC.TAX.EXPT.ZS',
#  'Taxes on goods and services (current LCU)': 'GC.TAX.GSRV.CN',
#  'Taxes on goods and services (% of revenue)': 'GC.TAX.GSRV.RV.ZS',
#  'Taxes on goods and services (% value added of industry and services)': 'GC.TAX.GSRV.VA.ZS',
#  'Customs and other import duties (current LCU)': 'GC.TAX.IMPT.CN',
#  'Customs and other import duties (% of tax revenue)': 'GC.TAX.IMPT.ZS',
#  'Taxes on international trade (current LCU)': 'GC.TAX.INTT.CN',
#  'Taxes on international trade (% of revenue)': 'GC.TAX.INTT.RV.ZS',
#  'Other taxes (current LCU)': 'GC.TAX.OTHR.CN',
#  'Other taxes (% of revenue)': 'GC.TAX.OTHR.RV.ZS',
#  'Tax revenue (current LCU)': 'GC.TAX.TOTL.CN',
#  'Tax revenue (% of GDP)': 'GC.TAX.TOTL.GD.ZS',
#  'Taxes on income, profits and capital gains (current LCU)': 'GC.TAX.YPKG.CN',
#  'Taxes on income, profits and capital gains (% of revenue)': 'GC.TAX.YPKG.RV.ZS',
#  'Taxes on income, profits and capital gains (% of total taxes)': 'GC.TAX.YPKG.ZS',
#  'Compensation of employees (current LCU)': 'GC.XPN.COMP.CN',
#  'Compensation of employees (% of expense)': 'GC.XPN.COMP.ZS',
#  'Goods and services expense (current LCU)': 'GC.XPN.GSRV.CN',
#  'Goods and services expense (% of expense)': 'GC.XPN.GSRV.ZS',
#  'Interest payments (current LCU)': 'GC.XPN.INTP.CN',
#  'Interest payments (% of revenue)': 'GC.XPN.INTP.RV.ZS',
#  'Interest payments (% of expense)': 'GC.XPN.INTP.ZS',
#  'Other expense (current LCU)': 'GC.XPN.OTHR.CN',
#  'Other expense (% of expense)': 'GC.XPN.OTHR.ZS',
#  'Expense (current LCU)': 'GC.XPN.TOTL.CN',
#  'Expense (% of GDP)': 'GC.XPN.TOTL.GD.ZS',
#  'Subsidies and other transfers (current LCU)': 'GC.XPN.TRFT.CN',
#  'Subsidies and other transfers (% of expense)': 'GC.XPN.TRFT.ZS',
#  'Distance to frontier score (0=lowest performance to 100=frontier)': 'IC.BUS.DFRN.XQ',
#  'Business extent of disclosure index (0=less disclosure to 10=more disclosure)': 'IC.BUS.DISC.XQ',
#  'Ease of doing business index (1=most business-friendly regulations)': 'IC.BUS.EASE.XQ',
#  'New business density (new registrations per 1,000 people ages 15-64)': 'IC.BUS.NDNS.ZS',
#  'New businesses registered (number)': 'IC.BUS.NREG',
#  'Depth of credit information index (0=low to 8=high)': 'IC.CRD.INFO.XQ',
#  'Private credit bureau coverage (% of adults)': 'IC.CRD.PRVT.ZS',
#  'Public credit registry coverage (% of adults)': 'IC.CRD.PUBL.ZS',
#  'Average time to clear exports through customs (days)': 'IC.CUS.DURS.EX',
#  'Delay in obtaining an electrical connection (days)': 'IC.ELC.DURS',
#  'Power outages in firms in a typical month (number)': 'IC.ELC.OUTG',
#  'Time required to get electricity (days)': 'IC.ELC.TIME',
#  'Cost to export (US$ per container)': 'IC.EXP.COST.CD',
#  'Cost to export, border compliance (US$)': 'IC.EXP.CSBC.CD',
#  'Cost to export, documentary compliance (US$)': 'IC.EXP.CSDC.CD',
#  'Documents to export (number)': 'IC.EXP.DOCS',
#  'Time to export (days)': 'IC.EXP.DURS',
#  'Time to export, border compliance (hours)': 'IC.EXP.TMBC',
#  'Time to export, documentary compliance (hours)': 'IC.EXP.TMDC',
#  'Firms using banks to finance working capital (% of firms)': 'IC.FRM.BKWC.ZS',
#  'Firms using banks to finance investment (% of firms)': 'IC.FRM.BNKS.ZS',
#  'Bribery incidence (% of firms experiencing at least one bribe payment request)': 'IC.FRM.BRIB.ZS',
#  'Firms competing against unregistered firms (% of firms)': 'IC.FRM.CMPU.ZS',
#  'Informal payments to public officials (% of firms)': 'IC.FRM.CORR.ZS',
#  'Losses due to theft, robbery, vandalism, and arson (% sales)': 'IC.FRM.CRIM.ZS',
#  'Time required to obtain an operating license (days)': 'IC.FRM.DURS',
#  'Firms with female top manager (% of firms)': 'IC.FRM.FEMM.ZS',
#  'Firms with female participation in ownership (% of firms)': 'IC.FRM.FEMO.ZS',
#  'Firms formally registered when operations started (% of firms)': 'IC.FRM.FREG.ZS',
#  'Firms that do not report all sales for tax purposes (% of firms)': 'IC.FRM.INFM.ZS',
#  'Internationally-recognized quality certification (% of firms)': 'IC.FRM.ISOC.ZS',
#  'Value lost due to electrical outages (% of sales)': 'IC.FRM.OUTG.ZS',
#  'Firms offering formal training (% of firms)': 'IC.FRM.TRNG.ZS',
#  'Time spent dealing with the requirements of government regulations (% of senior management time)': 'IC.GOV.DURS.ZS',
#  'Cost to import (US$ per container)': 'IC.IMP.COST.CD',
#  'Cost to import, border compliance (US$)': 'IC.IMP.CSBC.CD',
#  'Cost to import, documentary compliance (US$)': 'IC.IMP.CSDC.CD',
#  'Documents to import (number)': 'IC.IMP.DOCS',
#  'Time to import (days)': 'IC.IMP.DURS',
#  'Time to import, border compliance (hours)': 'IC.IMP.TMBC',
#  'Time to import, documentary compliance (hours)': 'IC.IMP.TMDC',
#  'Time to resolve insolvency (years)': 'IC.ISV.DURS',
#  'Strength of legal rights index (0=weak to 12=strong)': 'IC.LGL.CRED.XQ',
#  'Time required to enforce a contract (days)': 'IC.LGL.DURS',
#  'Time required to register property (days)': 'IC.PRP.DURS',
#  'Procedures to register property (number)': 'IC.PRP.PROC',
#  'Cost of business start-up procedures, female (% of GNI per capita)': 'IC.REG.COST.PC.FE.ZS',
#  'Cost of business start-up procedures, male (% of GNI per capita)': 'IC.REG.COST.PC.MA.ZS',
#  'Cost of business start-up procedures (% of GNI per capita)': 'IC.REG.COST.PC.ZS',
#  'Time required to start a business (days)': 'IC.REG.DURS',
#  'Time required to start a business, female (days)': 'IC.REG.DURS.FE',
#  'Time required to start a business, male (days)': 'IC.REG.DURS.MA',
#  'Start-up procedures to register a business (number)': 'IC.REG.PROC',
#  'Start-up procedures to register a business, female (number)': 'IC.REG.PROC.FE',
#  'Start-up procedures to register a business, male (number)': 'IC.REG.PROC.MA',
#  'Time to prepare and pay taxes (hours)': 'IC.TAX.DURS',
#  'Firms expected to give gifts in meetings with tax officials (% of firms)': 'IC.TAX.GIFT.ZS',
#  'Labor tax and contributions (% of commercial profits)': 'IC.TAX.LABR.CP.ZS',
#  'Number of visits or required meetings with tax officials': 'IC.TAX.METG',
#  'Other taxes payable by businesses (% of commercial profits)': 'IC.TAX.OTHR.CP.ZS',
#  'Tax payments (number)': 'IC.TAX.PAYM',
#  'Profit tax (% of commercial profits)': 'IC.TAX.PRFT.CP.ZS',
#  'Total tax rate (% of commercial profits)': 'IC.TAX.TOTL.CP.ZS',
#  'Time required to build a warehouse (days)': 'IC.WRH.DURS',
#  'Procedures to build a warehouse (number)': 'IC.WRH.PROC',
#  'Investment in energy with private participation (current US$)': 'IE.PPI.ENGY.CD',
#  'Investment in telecoms with private participation (current US$)': 'IE.PPI.TELE.CD',
#  'Investment in transport with private participation (current US$)': 'IE.PPI.TRAN.CD',
#  'Investment in water and sanitation with private participation (current US$)': 'IE.PPI.WATR.CD',
#  'Industrial design applications, nonresident, by count': 'IP.IDS.NRCT',
#  'Industrial design applications, resident, by count': 'IP.IDS.RSCT',
#  'Scientific and technical journal articles': 'IP.JRN.ARTC.SC',
#  'Patent applications, nonresidents': 'IP.PAT.NRES',
#  'Patent applications, residents': 'IP.PAT.RESD',
#  'Trademark applications, nonresident, by count': 'IP.TMK.NRCT',
#  'Trademark applications, direct nonresident': 'IP.TMK.NRES',
#  'Trademark applications, direct resident': 'IP.TMK.RESD',
#  'Trademark applications, resident, by count': 'IP.TMK.RSCT',
#  'Trademark applications, total': 'IP.TMK.TOTL',
#  'CPIA business regulatory environment rating (1=low to 6=high)': 'IQ.CPA.BREG.XQ',
#  'CPIA debt policy rating (1=low to 6=high)': 'IQ.CPA.DEBT.XQ',
#  'CPIA economic management cluster average (1=low to 6=high)': 'IQ.CPA.ECON.XQ',
#  'CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)': 'IQ.CPA.ENVR.XQ',
#  'CPIA quality of budgetary and financial management rating (1=low to 6=high)': 'IQ.CPA.FINQ.XQ',
#  'CPIA financial sector rating (1=low to 6=high)': 'IQ.CPA.FINS.XQ',
#  'CPIA fiscal policy rating (1=low to 6=high)': 'IQ.CPA.FISP.XQ',
#  'CPIA gender equality rating (1=low to 6=high)': 'IQ.CPA.GNDR.XQ',
#  'CPIA building human resources rating (1=low to 6=high)': 'IQ.CPA.HRES.XQ',
#  'IDA resource allocation index (1=low to 6=high)': 'IQ.CPA.IRAI.XQ',
#  'CPIA macroeconomic management rating (1=low to 6=high)': 'IQ.CPA.MACR.XQ',
#  'CPIA quality of public administration rating (1=low to 6=high)': 'IQ.CPA.PADM.XQ',
#  'CPIA equity of public resource use rating (1=low to 6=high)': 'IQ.CPA.PRES.XQ',
#  'CPIA property rights and rule-based governance rating (1=low to 6=high)': 'IQ.CPA.PROP.XQ',
#  'CPIA social protection rating (1=low to 6=high)': 'IQ.CPA.PROT.XQ',
#  'CPIA public sector management and institutions cluster average (1=low to 6=high)': 'IQ.CPA.PUBS.XQ',
#  'CPIA efficiency of revenue mobilization rating (1=low to 6=high)': 'IQ.CPA.REVN.XQ',
#  'CPIA policies for social inclusion/equity cluster average (1=low to 6=high)': 'IQ.CPA.SOCI.XQ',
#  'CPIA structural policies cluster average (1=low to 6=high)': 'IQ.CPA.STRC.XQ',
#  'CPIA trade rating (1=low to 6=high)': 'IQ.CPA.TRAD.XQ',
#  'CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)': 'IQ.CPA.TRAN.XQ',
#  'Methodology assessment of statistical capacity (scale 0 - 100)': 'IQ.SCI.MTHD',
#  'Overall level of statistical capacity (scale 0 - 100)': 'IQ.SCI.OVRL',
#  'Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)': 'IQ.SCI.PRDC',
#  'Source data assessment of statistical capacity (scale 0 - 100)': 'IQ.SCI.SRCE',
#  'Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)': 'IQ.WEF.CUST.XQ',
#  'Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficient by international standards)': 'IQ.WEF.PORT.XQ',
#  'Air transport, registered carrier departures worldwide': 'IS.AIR.DPRT',
#  'Air transport, freight (million ton-km)': 'IS.AIR.GOOD.MT.K1',
#  'Air transport, passengers carried': 'IS.AIR.PSGR',
#  'Railways, goods transported (million ton-km)': 'IS.RRS.GOOD.MT.K6',
#  'Railways, passengers carried (million passenger-km)': 'IS.RRS.PASG.KM',
#  'Rail lines (total route-km)': 'IS.RRS.TOTL.KM',
#  'Liner shipping connectivity index (maximum value in 2004 = 100)': 'IS.SHP.GCNW.XQ',
#  'Container port traffic (TEU: 20 foot equivalent units)': 'IS.SHP.GOOD.TU',
#  'Mobile cellular subscriptions': 'IT.CEL.SETS',
#  'Mobile cellular subscriptions (per 100 people)': 'IT.CEL.SETS.P2',
#  'Fixed telephone subscriptions': 'IT.MLT.MAIN',
#  'Fixed telephone subscriptions (per 100 people)': 'IT.MLT.MAIN.P2',
#  'Fixed broadband subscriptions': 'IT.NET.BBND',
#  'Fixed broadband subscriptions (per 100 people)': 'IT.NET.BBND.P2',
#  'Secure Internet servers': 'IT.NET.SECR',
#  'Secure Internet servers (per 1 million people)': 'IT.NET.SECR.P6',
#  'Individuals using the Internet (% of population)': 'IT.NET.USER.ZS',
# ...
#  'Adjusted net savings, excluding particulate emission damage (current US$)': 'NY.ADJ.SVNX.CD',
#  'Adjusted net savings, excluding particulate emission damage (% of GNI)': 'NY.ADJ.SVNX.GN.ZS',
#  'Exports as a capacity to import (constant LCU)': 'NY.EXP.CAPM.KN',
#  'Coal rents (% of GDP)': 'NY.GDP.COAL.RT.ZS',
#  'Inflation, GDP deflator (annual %)': 'NY.GDP.DEFL.KD.ZG',
#  'Inflation, GDP deflator: linked series (annual %)': 'NY.GDP.DEFL.KD.ZG.AD',
#  'GDP deflator (base year varies by country)': 'NY.GDP.DEFL.ZS',
#  'GDP deflator: linked series (base year varies by country)': 'NY.GDP.DEFL.ZS.AD',
#  'Discrepancy in expenditure estimate of GDP (current LCU)': 'NY.GDP.DISC.CN',
#  'Discrepancy in expenditure estimate of GDP (constant LCU)': 'NY.GDP.DISC.KN',
#  'Gross value added at factor cost (current US$)': 'NY.GDP.FCST.CD',
#  'Gross value added at factor cost (current LCU)': 'NY.GDP.FCST.CN',
#  'Gross value added at factor cost (constant 2010 US$)': 'NY.GDP.FCST.KD',
#  'Gross value added at factor cost (constant LCU)': 'NY.GDP.FCST.KN',
#  'Forest rents (% of GDP)': 'NY.GDP.FRST.RT.ZS',
#  'Mineral rents (% of GDP)': 'NY.GDP.MINR.RT.ZS',
#  'GDP (current US$)': 'NY.GDP.MKTP.CD',
#  'GDP (current LCU)': 'NY.GDP.MKTP.CN',
#  'GDP at market prices: linked series (current LCU)': 'NY.GDP.MKTP.CN.AD',
#  'GDP (constant 2010 US$)': 'NY.GDP.MKTP.KD',
#  'GDP growth (annual %)': 'NY.GDP.MKTP.KD.ZG',
#  'GDP (constant LCU)': 'NY.GDP.MKTP.KN',
#  'GDP, PPP (current international $)': 'NY.GDP.MKTP.PP.CD',
#  'GDP, PPP (constant 2011 international $)': 'NY.GDP.MKTP.PP.KD',
#  'Natural gas rents (% of GDP)': 'NY.GDP.NGAS.RT.ZS',
#  'GDP per capita (current US$)': 'NY.GDP.PCAP.CD',
#  'GDP per capita (current LCU)': 'NY.GDP.PCAP.CN',
#  'GDP per capita (constant 2010 US$)': 'NY.GDP.PCAP.KD',
#  'GDP per capita growth (annual %)': 'NY.GDP.PCAP.KD.ZG',
#  'GDP per capita (constant LCU)': 'NY.GDP.PCAP.KN',
#  'GDP per capita, PPP (current international $)': 'NY.GDP.PCAP.PP.CD',
#  'GDP per capita, PPP (constant 2011 international $)': 'NY.GDP.PCAP.PP.KD',
#  'Oil rents (% of GDP)': 'NY.GDP.PETR.RT.ZS',
#  'Total natural resources rents (% of GDP)': 'NY.GDP.TOTL.RT.ZS',
#  'Gross domestic savings (current US$)': 'NY.GDS.TOTL.CD',
#  'Gross domestic savings (current LCU)': 'NY.GDS.TOTL.CN',
#  'Gross domestic savings (% of GDP)': 'NY.GDS.TOTL.ZS',
#  'Gross domestic income (constant LCU)': 'NY.GDY.TOTL.KN',
#  'GNI, Atlas method (current US$)': 'NY.GNP.ATLS.CD',
#  'GNI (current US$)': 'NY.GNP.MKTP.CD',
#  'GNI (current LCU)': 'NY.GNP.MKTP.CN',
#  'GNI (constant 2010 US$)': 'NY.GNP.MKTP.KD',
#  'GNI growth (annual %)': 'NY.GNP.MKTP.KD.ZG',
#  'GNI (constant LCU)': 'NY.GNP.MKTP.KN',
#  'GNI, PPP (current international $)': 'NY.GNP.MKTP.PP.CD',
#  'GNI, PPP (constant 2011 international $)': 'NY.GNP.MKTP.PP.KD',
#  'GNI per capita, Atlas method (current US$)': 'NY.GNP.PCAP.CD',
#  'GNI per capita (current LCU)': 'NY.GNP.PCAP.CN',
#  'GNI per capita (constant 2010 US$)': 'NY.GNP.PCAP.KD',
#  'GNI per capita growth (annual %)': 'NY.GNP.PCAP.KD.ZG',
#  'GNI per capita (constant LCU)': 'NY.GNP.PCAP.KN',
#  'GNI per capita, PPP (current international $)': 'NY.GNP.PCAP.PP.CD',
#  'GNI per capita, PPP (constant 2011 international $)': 'NY.GNP.PCAP.PP.KD',
#  'Gross savings (current US$)': 'NY.GNS.ICTR.CD',
#  'Gross savings (current LCU)': 'NY.GNS.ICTR.CN',
#  'Gross savings (% of GNI)': 'NY.GNS.ICTR.GN.ZS',
#  'Gross savings (% of GDP)': 'NY.GNS.ICTR.ZS',
#  'Net income from abroad (current US$)': 'NY.GSR.NFCY.CD',
#  'Net income from abroad (current LCU)': 'NY.GSR.NFCY.CN',
#  'Net income from abroad (constant LCU)': 'NY.GSR.NFCY.KN',
#  'Net taxes on products (current US$)': 'NY.TAX.NIND.CD',
#  'Net taxes on products (current LCU)': 'NY.TAX.NIND.CN',
#  'Net taxes on products (constant LCU)': 'NY.TAX.NIND.KN',
#  'Net current transfers from abroad (current US$)': 'NY.TRF.NCTR.CD',
#  'Net current transfers from abroad (current LCU)': 'NY.TRF.NCTR.CN',
#  'Net current transfers from abroad (constant LCU)': 'NY.TRF.NCTR.KN',
#  'Terms of trade adjustment (constant LCU)': 'NY.TTF.GNFS.KN',
#  'DEC alternative conversion factor (LCU per US$)': 'PA.NUS.ATLS',
#  'Official exchange rate (LCU per US$, period average)': 'PA.NUS.FCRF',
#  'PPP conversion factor, GDP (LCU per international $)': 'PA.NUS.PPP',
#  '2005 PPP conversion factor, GDP (LCU per international $)': 'PA.NUS.PPP.05',
#  'Price level ratio of PPP conversion factor (GDP) to market exchange rate': 'PA.NUS.PPPC.RF',
#  'PPP conversion factor, private consumption (LCU per international $)': 'PA.NUS.PRVT.PP',
#  '2005 PPP conversion factor, private consumption (LCU per international $)': 'PA.NUS.PRVT.PP.05',
#  'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)': 'per_allsp.adq_pop_tot',
#  'Benefit incidence of social protection and labor programs to poorest quintile (% of total SPL benefits)': 'per_allsp.ben_q1_tot',
#  'Coverage of social protection and labor programs (% of population)': 'per_allsp.cov_pop_tot',
#  'Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)': 'per_lm_alllm.adq_pop_tot',
#  'Benefit incidence of unemployment benefits and ALMP to poorest quintile (% of total U/ALMP benefits)': 'per_lm_alllm.ben_q1_tot',
#  'Coverage of unemployment benefits and ALMP (% of population)': 'per_lm_alllm.cov_pop_tot',
#  'Coverage of unemployment benefits and ALMP in poorest quintile (% of population)': 'per_lm_alllm.cov_q1_tot',
#  'Coverage of unemployment benefits and ALMP in 2nd quintile (% of population)': 'per_lm_alllm.cov_q2_tot',
#  'Coverage of unemployment benefits and ALMP in 3rd quintile (% of population)': 'per_lm_alllm.cov_q3_tot',
#  'Coverage of unemployment benefits and ALMP in 4th quintile (% of population)': 'per_lm_alllm.cov_q4_tot',
#  'Coverage of unemployment benefits and ALMP in richest quintile (% of population)': 'per_lm_alllm.cov_q5_tot',
#  'Adequacy of social safety net programs (% of total welfare of beneficiary households)': 'per_sa_allsa.adq_pop_tot',
#  'Benefit incidence of social safety net programs to poorest quintile (% of total safety net benefits)': 'per_sa_allsa.ben_q1_tot',
#  'Coverage of social safety net programs (% of population)': 'per_sa_allsa.cov_pop_tot',
#  'Coverage of social safety net programs in poorest quintile (% of population)': 'per_sa_allsa.cov_q1_tot',
#  'Coverage of social safety net programs in 2nd quintile (% of population)': 'per_sa_allsa.cov_q2_tot',
#  'Coverage of social safety net programs in 3rd quintile (% of population)': 'per_sa_allsa.cov_q3_tot',
#  'Coverage of social safety net programs in 4th quintile (% of population)': 'per_sa_allsa.cov_q4_tot',
#  'Coverage of social safety net programs in richest quintile (% of population)': 'per_sa_allsa.cov_q5_tot',
#  'Adequacy of social insurance programs (% of total welfare of beneficiary households)': 'per_si_allsi.adq_pop_tot',
#  'Benefit incidence of social insurance programs to poorest quintile (% of total social insurance benefits)': 'per_si_allsi.ben_q1_tot',
#  'Coverage of social insurance programs (% of population)': 'per_si_allsi.cov_pop_tot',
#  'Coverage of social insurance programs in poorest quintile (% of population)': 'per_si_allsi.cov_q1_tot',
#  'Coverage of social insurance programs in 2nd quintile (% of population)': 'per_si_allsi.cov_q2_tot',
#  'Coverage of social insurance programs in 3rd quintile (% of population)': 'per_si_allsi.cov_q3_tot',
#  'Coverage of social insurance programs in 4th quintile (% of population)': 'per_si_allsi.cov_q4_tot',
#  'Coverage of social insurance programs in richest quintile (% of population)': 'per_si_allsi.cov_q5_tot',
#  'Real effective exchange rate index (2010 = 100)': 'PX.REX.REER',
#  'Literacy rate, youth female (% of females ages 15-24)': 'SE.ADT.1524.LT.FE.ZS',
#  'Literacy rate, youth (ages 15-24), gender parity index (GPI)': 'SE.ADT.1524.LT.FM.ZS',
#  'Literacy rate, youth male (% of males ages 15-24)': 'SE.ADT.1524.LT.MA.ZS',
#  'Literacy rate, youth total (% of people ages 15-24)': 'SE.ADT.1524.LT.ZS',
#  'Literacy rate, adult female (% of females ages 15 and above)': 'SE.ADT.LITR.FE.ZS',
#  'Literacy rate, adult male (% of males ages 15 and above)': 'SE.ADT.LITR.MA.ZS',
#  'Literacy rate, adult total (% of people ages 15 and above)': 'SE.ADT.LITR.ZS',
#  'Compulsory education, duration (years)': 'SE.COM.DURS',
#  'School enrollment, primary (gross), gender parity index (GPI)': 'SE.ENR.PRIM.FM.ZS',
#  'School enrollment, primary and secondary (gross), gender parity index (GPI)': 'SE.ENR.PRSC.FM.ZS',
#  'School enrollment, secondary (gross), gender parity index (GPI)': 'SE.ENR.SECO.FM.ZS',
#  'School enrollment, tertiary (gross), gender parity index (GPI)': 'SE.ENR.TERT.FM.ZS',
#  'Preprimary education, duration (years)': 'SE.PRE.DURS',
#  'Pupil-teacher ratio, preprimary': 'SE.PRE.ENRL.TC.ZS',
#  'School enrollment, preprimary (% gross)': 'SE.PRE.ENRR',
#  'School enrollment, preprimary, female (% gross)': 'SE.PRE.ENRR.FE',
#  'School enrollment, preprimary, male (% gross)': 'SE.PRE.ENRR.MA',
#  'Trained teachers in preprimary education, female (% of female teachers)': 'SE.PRE.TCAQ.FE.ZS',
#  'Trained teachers in preprimary education, male (% of male teachers)': 'SE.PRE.TCAQ.MA.ZS',
#  'Trained teachers in preprimary education (% of total teachers)': 'SE.PRE.TCAQ.ZS',
#  'Primary school starting age (years)': 'SE.PRM.AGES',
#  'Primary completion rate, female (% of relevant age group)': 'SE.PRM.CMPT.FE.ZS',
#  'Primary completion rate, male (% of relevant age group)': 'SE.PRM.CMPT.MA.ZS',
#  'Primary completion rate, total (% of relevant age group)': 'SE.PRM.CMPT.ZS',
#  'Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)': 'SE.PRM.CUAT.FE.ZS',
#  'Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)': 'SE.PRM.CUAT.MA.ZS',
#  'Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)': 'SE.PRM.CUAT.ZS',
#  'Primary education, duration (years)': 'SE.PRM.DURS',
#  'Primary education, pupils': 'SE.PRM.ENRL',
#  'Primary education, pupils (% female)': 'SE.PRM.ENRL.FE.ZS',
#  'Pupil-teacher ratio, primary': 'SE.PRM.ENRL.TC.ZS',
#  'School enrollment, primary (% gross)': 'SE.PRM.ENRR',
#  'School enrollment, primary, female (% gross)': 'SE.PRM.ENRR.FE',
#  'School enrollment, primary, male (% gross)': 'SE.PRM.ENRR.MA',
#  'Gross intake ratio in first grade of primary education, female (% of relevant age group)': 'SE.PRM.GINT.FE.ZS',
#  'Gross intake ratio in first grade of primary education, male (% of relevant age group)': 'SE.PRM.GINT.MA.ZS',
#  'Gross intake ratio in first grade of primary education, total (% of relevant age group)': 'SE.PRM.GINT.ZS',
#  'School enrollment, primary (% net)': 'SE.PRM.NENR',
#  'School enrollment, primary, female (% net)': 'SE.PRM.NENR.FE',
#  'School enrollment, primary, male (% net)': 'SE.PRM.NENR.MA',
#  'Net intake rate in grade 1, female (% of official school-age population)': 'SE.PRM.NINT.FE.ZS',
#  'Net intake rate in grade 1, male (% of official school-age population)': 'SE.PRM.NINT.MA.ZS',
#  'Net intake rate in grade 1 (% of official school-age population)': 'SE.PRM.NINT.ZS',
#  'Over-age students, primary, female (% of female enrollment)': 'SE.PRM.OENR.FE.ZS',
#  'Over-age students, primary, male (% of male enrollment)': 'SE.PRM.OENR.MA.ZS',
#  'Over-age students, primary (% of enrollment)': 'SE.PRM.OENR.ZS',
#  'School enrollment, primary, private (% of total primary)': 'SE.PRM.PRIV.ZS',
#  'Persistence to grade 5, female (% of cohort)': 'SE.PRM.PRS5.FE.ZS',
#  'Persistence to grade 5, male (% of cohort)': 'SE.PRM.PRS5.MA.ZS',
#  'Persistence to grade 5, total (% of cohort)': 'SE.PRM.PRS5.ZS',
#  'Persistence to last grade of primary, female (% of cohort)': 'SE.PRM.PRSL.FE.ZS',
#  'Persistence to last grade of primary, male (% of cohort)': 'SE.PRM.PRSL.MA.ZS',
#  'Persistence to last grade of primary, total (% of cohort)': 'SE.PRM.PRSL.ZS',
#  'Repeaters, primary, female (% of female enrollment)': 'SE.PRM.REPT.FE.ZS',
#  'Repeaters, primary, male (% of male enrollment)': 'SE.PRM.REPT.MA.ZS',
#  'Repeaters, primary, total (% of total enrollment)': 'SE.PRM.REPT.ZS',
#  'Trained teachers in primary education, female (% of female teachers)': 'SE.PRM.TCAQ.FE.ZS',
#  'Trained teachers in primary education, male (% of male teachers)': 'SE.PRM.TCAQ.MA.ZS',
#  'Trained teachers in primary education (% of total teachers)': 'SE.PRM.TCAQ.ZS',
#  'Primary education, teachers': 'SE.PRM.TCHR',
#  'Primary education, teachers (% female)': 'SE.PRM.TCHR.FE.ZS',
#  'Adjusted net enrollment rate, primary (% of primary school age children)': 'SE.PRM.TENR',
#  'Adjusted net enrollment rate, primary, female (% of primary school age children)': 'SE.PRM.TENR.FE',
#  'Adjusted net enrollment rate, primary, male (% of primary school age children)': 'SE.PRM.TENR.MA',
#  'Children out of school, primary': 'SE.PRM.UNER',
#  'Children out of school, primary, female': 'SE.PRM.UNER.FE',
#  'Children out of school, female (% of female primary school age)': 'SE.PRM.UNER.FE.ZS',
#  'Children out of school, primary, male': 'SE.PRM.UNER.MA',
#  'Children out of school, male (% of male primary school age)': 'SE.PRM.UNER.MA.ZS',
#  'Children out of school (% of primary school age)': 'SE.PRM.UNER.ZS',
#  'Lower secondary school starting age (years)': 'SE.SEC.AGES',
#  'Lower secondary completion rate, female (% of relevant age group)': 'SE.SEC.CMPT.LO.FE.ZS',
#  'Lower secondary completion rate, male (% of relevant age group)': 'SE.SEC.CMPT.LO.MA.ZS',
#  'Lower secondary completion rate, total (% of relevant age group)': 'SE.SEC.CMPT.LO.ZS',
#  'Educational attainment, at least completed lower secondary, population 25+, female (%) (cumulative)': 'SE.SEC.CUAT.LO.FE.ZS',
#  'Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)': 'SE.SEC.CUAT.LO.MA.ZS',
#  'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)': 'SE.SEC.CUAT.LO.ZS',
#  'Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative)': 'SE.SEC.CUAT.PO.FE.ZS',
#  'Educational attainment, at least completed post-secondary, population 25+, male (%) (cumulative)': 'SE.SEC.CUAT.PO.MA.ZS',
#  'Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)': 'SE.SEC.CUAT.PO.ZS',
#  'Educational attainment, at least completed upper secondary, population 25+, female (%) (cumulative)': 'SE.SEC.CUAT.UP.FE.ZS',
#  'Educational attainment, at least completed upper secondary, population 25+, male (%) (cumulative)': 'SE.SEC.CUAT.UP.MA.ZS',
#  'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)': 'SE.SEC.CUAT.UP.ZS',
#  'Secondary education, duration (years)': 'SE.SEC.DURS',
#  'Secondary education, pupils': 'SE.SEC.ENRL',
#  'Secondary education, pupils (% female)': 'SE.SEC.ENRL.FE.ZS',
#  'Secondary education, general pupils': 'SE.SEC.ENRL.GC',
#  'Secondary education, general pupils (% female)': 'SE.SEC.ENRL.GC.FE.ZS',
#  'Pupil-teacher ratio, lower secondary': 'SE.SEC.ENRL.LO.TC.ZS',
#  'Pupil-teacher ratio, secondary': 'SE.SEC.ENRL.TC.ZS',
#  'Pupil-teacher ratio, upper secondary': 'SE.SEC.ENRL.UP.TC.ZS',
#  'Secondary education, vocational pupils': 'SE.SEC.ENRL.VO',
#  'Secondary education, vocational pupils (% female)': 'SE.SEC.ENRL.VO.FE.ZS',
#  'School enrollment, secondary (% gross)': 'SE.SEC.ENRR',
#  'School enrollment, secondary, female (% gross)': 'SE.SEC.ENRR.FE',
#  'School enrollment, secondary, male (% gross)': 'SE.SEC.ENRR.MA',
#  'School enrollment, secondary (% net)': 'SE.SEC.NENR',
#  'School enrollment, secondary, female (% net)': 'SE.SEC.NENR.FE',
#  'School enrollment, secondary, male (% net)': 'SE.SEC.NENR.MA',
#  'School enrollment, secondary, private (% of total secondary)': 'SE.SEC.PRIV.ZS',
#  'Progression to secondary school, female (%)': 'SE.SEC.PROG.FE.ZS',
#  'Progression to secondary school, male (%)': 'SE.SEC.PROG.MA.ZS',
#  'Progression to secondary school (%)': 'SE.SEC.PROG.ZS',
#  ...}

# %% [markdown]
# We add a key that is not included in the dictionary

# %%
the_dictionary['Net official development assistance received (constant 2013 US$)'] = 'DT.ODA.ODAT.KD'

# %%
code_to_name_dict = {}

# %%
len(list_of_indicator_codes)
# Out:
# 172

# %%
list_of_indicator_codes.remove('Year')

# %%
len(list_of_indicator_codes)
# Out:
# 171

# %%
len(list_of_indicator_names)
# Out:
# 171

# %%
len(list_of_indicator_codes)==len(list_of_indicator_names)
# Out:
# True

# %%
code_to_name_dict = {}

# %%
counter = 0
for code in list_of_indicator_codes:
    code_to_name_dict[code] = list_of_indicator_names[counter]
    counter+=1

# %%
code_to_name_dict
# Out:
# {'EN.ATM.CO2E.KD.GD': 'CO2 emissions (kg per 2010 US$ of GDP)',
#  'NY.GNP.MKTP.KN': 'GNI (constant LCU)',
#  'NY.GNP.MKTP.CN': 'GNI (current LCU)',
#  'NY.GNP.PCAP.KD.ZG': 'GNI per capita growth (annual %)',
#  'NY.GNP.MKTP.KD': 'GNI (constant 2010 US$)',
#  'NE.CON.GOVT.CN': 'General government final consumption expenditure (current LCU)',
#  'DC.DAC.GBRL.CD': 'Net bilateral aid flows from DAC donors, United Kingdom (current US$)',
#  'AG.PRD.FOOD.XD': 'Food production index (2004-2006 = 100)',
#  'NE.CON.PRVT.KD.ZG': 'Household final consumption expenditure (annual % growth)',
#  'AG.LND.CROP.ZS': 'Permanent cropland (% of land area)',
#  'NY.GNP.PCAP.KD': 'GNI per capita (constant 2010 US$)',
#  'SP.POP.DPND.YG': 'Age dependency ratio, young (% of working-age population)',
#  'EN.POP.DNST': 'Population density (people per sq. km of land area)',
#  'NV.IND.TOTL.KD.ZG': 'Industry, value added (annual % growth)',
#  'SP.POP.DPND.OL': 'Age dependency ratio, old (% of working-age population)',
#  'NY.GNP.PCAP.KN': 'GNI per capita (constant LCU)',
#  'AG.LND.CREL.HA': 'Land under cereal production (hectares)',
#  'AG.LND.AGRI.K2': 'Agricultural land (sq. km)',
#  'AG.YLD.CREL.KG': 'Cereal yield (kg per hectare)',
#  'AG.PRD.CREL.MT': 'Cereal production (metric tons)',
#  'NV.AGR.TOTL.KN': 'Agriculture, value added (constant LCU)',
#  'NE.CON.PETC.KD.ZG': 'Household final consumption expenditure, etc. (annual % growth)',
#  'NE.GDI.TOTL.KD.ZG': 'Gross capital formation (annual % growth)',
#  'ER.FSH.AQUA.MT': 'Aquaculture production (metric tons)',
#  'NE.CON.TETC.CN': 'Final consumption expenditure, etc. (current LCU)',
#  'NE.CON.TETC.KN': 'Final consumption expenditure, etc. (constant LCU)',
#  'NE.CON.TETC.KD': 'Final consumption expenditure, etc. (constant 2010 US$)',
#  'MS.MIL.MPRT.KD': 'Arms imports (SIPRI trend indicator values)',
#  'NE.CON.TETC.ZS': 'Final consumption expenditure, etc. (% of GDP)',
#  'NE.CON.TOTL.CN': 'Final consumption expenditure (current LCU)',
#  'NE.CON.TOTL.KN': 'Final consumption expenditure (constant LCU)',
#  'NE.CON.TOTL.KD': 'Final consumption expenditure (constant 2010 US$)',
#  'NV.AGR.TOTL.CN': 'Agriculture, value added (current LCU)',
#  'NE.CON.GOVT.KD.ZG': 'General government final consumption expenditure (annual % growth)',
#  'NV.AGR.TOTL.KD': 'Agriculture, value added (constant 2010 US$)',
#  'NV.AGR.TOTL.ZS': 'Agriculture, value added (% of GDP)',
#  'AG.SRF.TOTL.K2': 'Surface area (sq. km)',
#  'AG.PRD.CROP.XD': 'Crop production index (2004-2006 = 100)',
#  'NE.CON.GOVT.KD': 'General government final consumption expenditure (constant 2010 US$)',
#  'NE.EXP.GNFS.KD.ZG': 'Exports of goods and services (annual % growth)',
#  'NE.CON.GOVT.KN': 'General government final consumption expenditure (constant LCU)',
#  'NE.CON.GOVT.ZS': 'General government final consumption expenditure (% of GDP)',
#  'NE.CON.PRVT.PC.KD.ZG': 'Household final consumption expenditure per capita growth (annual %)',
#  'AG.LND.AGRI.ZS': 'Agricultural land (% of land area)',
#  'NY.GNP.MKTP.KD.ZG': 'GNI growth (annual %)',
#  'EN.URB.LCTY.UR.ZS': 'Population in the largest city (% of urban population)',
#  'NE.EXP.GNFS.CN': 'Exports of goods and services (current LCU)',
#  'EN.URB.LCTY': 'Population in largest city',
#  'TM.VAL.MRCH.CD.WT': 'Merchandise imports (current US$)',
#  'SP.POP.GROW': 'Population growth (annual %)',
#  'NE.EXP.GNFS.KN': 'Exports of goods and services (constant LCU)',
#  'NV.IND.TOTL.ZS': 'Industry, value added (% of GDP)',
#  'ER.FSH.CAPT.MT': 'Capture fisheries production (metric tons)',
#  'NE.RSB.GNFS.ZS': 'External balance on goods and services (% of GDP)',
#  'TM.VAL.MRCH.RS.ZS': 'Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#  'SP.POP.65UP.TO.ZS': 'Population ages 65 and above (% of total)',
#  'NE.RSB.GNFS.KN': 'External balance on goods and services (constant LCU)',
#  'TM.VAL.MRCH.WL.CD': 'Merchandise imports by the reporting economy (current US$)',
#  'SP.POP.1564.TO.ZS': 'Population ages 15-64 (% of total)',
#  'EN.URB.MCTY': 'Population in urban agglomerations of more than 1 million',
#  'EN.URB.MCTY.TL.ZS': 'Population in urban agglomerations of more than 1 million (% of total population)',
#  'SP.RUR.TOTL.ZG': 'Rural population growth (annual %)',
#  'SP.RUR.TOTL.ZS': 'Rural population (% of total population)',
#  'NE.EXP.GNFS.ZS': 'Exports of goods and services (% of GDP)',
#  'SP.RUR.TOTL': 'Rural population',
#  'TX.VAL.MRCH.R1.ZS': 'Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#  'SP.POP.TOTL': 'Population, total',
#  'SP.POP.TOTL.FE.ZS': 'Population, female (% of total)',
#  'NE.EXP.GNFS.KD': 'Exports of goods and services (constant 2010 US$)',
#  'NY.EXP.CAPM.KN': 'Exports as a capacity to import (constant LCU)',
#  'TM.VAL.MRCH.HI.ZS': 'Merchandise imports from high-income economies (% of total merchandise imports)',
#  'SP.DYN.LE00.MA.IN': 'Life expectancy at birth, male (years)',
#  'SP.DYN.IMRT.IN': 'Mortality rate, infant (per 1,000 live births)',
#  'DT.ODA.ALLD.KD': 'Net official development assistance and official aid received (constant 2013 US$)',
#  'FP.CPI.TOTL.ZG': 'Inflation, consumer prices (annual %)',
#  'SH.DYN.MORT': 'Mortality rate, under-5 (per 1,000 live births)',
#  'DT.ODA.ODAT.PC.ZS': 'Net ODA received per capita (current US$)',
#  'DT.ODA.ALLD.CD': 'Net official development assistance and official aid received (current US$)',
#  'EN.ATM.CO2E.GF.ZS': 'CO2 emissions from gaseous fuel consumption (% of total)',
#  'DC.DAC.USAL.CD': 'Net bilateral aid flows from DAC donors, United States (current US$)',
#  'DC.DAC.DEUL.CD': 'Net bilateral aid flows from DAC donors, Germany (current US$)',
#  'DC.DAC.TOTL.CD': 'Net bilateral aid flows from DAC donors, Total (current US$)',
#  'NY.GSR.NFCY.CN': 'Net income from abroad (current LCU)',
#  'NE.RSB.GNFS.CN': 'External balance on goods and services (current LCU)',
#  'SP.DYN.AMRT.MA': 'Mortality rate, adult, male (per 1,000 male adults)',
#  'DT.ODA.ODAT.CD': 'Net official development assistance received (current US$)',
#  'SP.POP.0014.TO.ZS': 'Population ages 0-14 (% of total)',
#  'NV.IND.TOTL.KD': 'Industry, value added (constant 2010 US$)',
#  'NV.IND.TOTL.KN': 'Industry, value added (constant LCU)',
#  'DT.ODA.ODAT.KD': 'Net official development assistance received (constant 2013 US$)',
#  'SP.DYN.CBRT.IN': 'Birth rate, crude (per 1,000 people)',
#  'SH.DTH.MORT': 'Number of under-five deaths',
#  'TM.VAL.MRCH.OR.ZS': 'Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#  'SH.DTH.IMRT': 'Number of infant deaths',
#  'NV.IND.TOTL.CN': 'Industry, value added (current LCU)',
#  'SP.DYN.AMRT.FE': 'Mortality rate, adult, female (per 1,000 female adults)',
#  'TM.VAL.MRCH.R5.ZS': 'Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#  'NE.IMP.GNFS.CN': 'Imports of goods and services (current LCU)',
#  'NY.GDP.DISC.CN': 'Discrepancy in expenditure estimate of GDP (current LCU)',
#  'NE.DAB.TOTL.CN': 'Gross national expenditure (current LCU)',
#  'SP.DYN.TFRT.IN': 'Fertility rate, total (births per woman)',
#  'NE.DAB.DEFL.ZS': 'Gross national expenditure deflator (base year varies by country)',
#  'SP.DYN.LE00.IN': 'Life expectancy at birth, total (years)',
#  'NE.CON.PRVT.KD': 'Household final consumption expenditure (constant 2010 US$)',
#  'NE.DAB.TOTL.KN': 'Gross national expenditure (constant LCU)',
#  'NE.CON.PRVT.KN': 'Household final consumption expenditure (constant LCU)',
#  'NE.CON.PRVT.PC.KD': 'Household final consumption expenditure per capita (constant 2010 US$)',
#  'NE.CON.PETC.ZS': 'Household final consumption expenditure, etc. (% of GDP)',
#  'EN.ATM.CO2E.GF.KT': 'CO2 emissions from gaseous fuel consumption (kt)',
#  'NE.CON.PETC.KD': 'Household final consumption expenditure, etc. (constant 2010 US$)',
#  'NE.CON.PETC.KN': 'Household final consumption expenditure, etc. (constant LCU)',
#  'NE.CON.PETC.CN': 'Household final consumption expenditure, etc. (current LCU)',
#  'NE.CON.PRVT.CN': 'Household final consumption expenditure (current LCU)',
#  'SP.URB.GROW': 'Urban population growth (annual %)',
#  'NE.DAB.TOTL.KD': 'Gross national expenditure (constant 2010 US$)',
#  'NY.GDS.TOTL.CN': 'Gross domestic savings (current LCU)',
#  'NE.DAB.TOTL.ZS': 'Gross national expenditure (% of GDP)',
#  'BX.GRT.EXTA.CD.WD': 'Grants, excluding technical cooperation (BoP, current US$)',
#  'NE.GDI.TOTL.KD': 'Gross capital formation (constant 2010 US$)',
#  'NE.GDI.TOTL.KN': 'Gross capital formation (constant LCU)',
#  'NE.GDI.TOTL.CN': 'Gross capital formation (current LCU)',
#  'NY.GDY.TOTL.KN': 'Gross domestic income (constant LCU)',
#  'NY.GDS.TOTL.ZS': 'Gross domestic savings (% of GDP)',
#  'EN.ATM.CO2E.KT': 'CO2 emissions (kt)',
#  'NE.GDI.TOTL.ZS': 'Gross capital formation (% of GDP)',
#  'TX.VAL.MRCH.RS.ZS': 'Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#  'SP.URB.TOTL.IN.ZS': 'Urban population (% of total)',
#  'NV.IND.MANF.KD': 'Manufacturing, value added (constant 2010 US$)',
#  'NV.SRV.TETC.CN': 'Services, etc., value added (current LCU)',
#  'FP.CPI.TOTL': 'Consumer price index (2010 = 100)',
#  'NE.IMP.GNFS.KD': 'Imports of goods and services (constant 2010 US$)',
#  'NV.IND.MANF.KN': 'Manufacturing, value added (constant LCU)',
#  'NV.SRV.TETC.KN': 'Services, etc., value added (constant LCU)',
#  'EN.ATM.CO2E.SF.KT': 'CO2 emissions from solid fuel consumption (kt)',
#  'NV.IND.MANF.CN': 'Manufacturing, value added (current LCU)',
#  'SP.DYN.CDRT.IN': 'Death rate, crude (per 1,000 people)',
#  'TX.VAL.MRCH.CD.WT': 'Merchandise exports (current US$)',
#  'NY.GDP.DISC.KN': 'Discrepancy in expenditure estimate of GDP (constant LCU)',
#  'NV.SRV.TETC.ZS': 'Services, etc., value added (% of GDP)',
#  'NE.IMP.GNFS.KN': 'Imports of goods and services (constant LCU)',
#  'TX.VAL.MRCH.WL.CD': 'Merchandise exports by the reporting economy (current US$)',
#  'NV.SRV.TETC.KD': 'Services, etc., value added (constant 2010 US$)',
#  'SP.URB.TOTL': 'Urban population',
#  'EN.ATM.CO2E.SF.ZS': 'CO2 emissions from solid fuel consumption (% of total)',
#  'NV.IND.MANF.ZS': 'Manufacturing, value added (% of GDP)',
#  'SP.DYN.LE00.FE.IN': 'Life expectancy at birth, female (years)',
#  'NE.TRD.GNFS.ZS': 'Trade (% of GDP)',
#  'FI.RES.XGLD.CD': 'Total reserves minus gold (current US$)',
#  'EN.ATM.CO2E.PC': 'CO2 emissions (metric tons per capita)',
#  'SP.DYN.TO65.FE.ZS': 'Survival to age 65, female (% of cohort)',
#  'FI.RES.TOTL.CD': 'Total reserves (includes gold, current US$)',
#  'NE.IMP.GNFS.ZS': 'Imports of goods and services (% of GDP)',
#  'NY.TTF.GNFS.KN': 'Terms of trade adjustment (constant LCU)',
#  'BX.GRT.TECH.CD.WD': 'Technical cooperation grants (BoP, current US$)',
#  'EN.ATM.CO2E.LF.ZS': 'CO2 emissions from liquid fuel consumption (% of total)',
#  'EN.ATM.CO2E.LF.KT': 'CO2 emissions from liquid fuel consumption (kt)',
#  'SP.DYN.TO65.MA.ZS': 'Survival to age 65, male (% of cohort)',
#  'ER.FSH.PROD.MT': 'Total fisheries production (metric tons)',
#  'AG.LND.ARBL.HA.PC': 'Arable land (hectares per person)',
#  'AG.LND.TOTL.K2': 'Land area (sq. km)',
#  'SP.POP.DPND': 'Age dependency ratio (% of working-age population)',
#  'NY.GNP.PCAP.CN': 'GNI per capita (current LCU)',
#  'NY.GDP.DEFL.KD.ZG': 'Inflation, GDP deflator (annual %)',
#  'NV.IND.MANF.KD.ZG': 'Manufacturing, value added (annual % growth)',
#  'AG.LND.ARBL.HA': 'Arable land (hectares)',
#  'NE.IMP.GNFS.KD.ZG': 'Imports of goods and services (annual % growth)',
#  'DC.DAC.JPNL.CD': 'Net bilateral aid flows from DAC donors, Japan (current US$)',
#  'SP.ADO.TFRT': 'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#  'AG.LND.ARBL.ZS': 'Arable land (% of land area)',
#  'AG.PRD.LVSK.XD': 'Livestock production index (2004-2006 = 100)',
#  'NV.SRV.TETC.KD.ZG': 'Services, etc., value added (annual % growth)'}

# %%
code_to_name_dict['NY.GNP.MKTP.KN']
# Out:
# 'GNI (constant LCU)'

# %%
pickle.dump(code_to_name_dict, open( WDI_path+"code_to_name_dict_of_indicator_names.p", "wb" ))

# %%
WDI_design_matrix_df = pd.read_csv(WDI_path+"completed_values_1962_2013_design_matrix.csv")

# %% [markdown]
# Let us load the **code-to-name dictionary**.

# %%
code_to_name_dict = pickle.load(open( WDI_path+"code_to_name_dict_of_indicator_names.p", "rb" ))

# %%
code_to_name_dict.keys()
# Out:
# dict_keys(['EN.ATM.CO2E.KD.GD', 'NY.GNP.MKTP.KN', 'NY.GNP.MKTP.CN', 'NY.GNP.PCAP.KD.ZG', 'NY.GNP.MKTP.KD', 'NE.CON.GOVT.CN', 'DC.DAC.GBRL.CD', 'AG.PRD.FOOD.XD', 'NE.CON.PRVT.KD.ZG', 'AG.LND.CROP.ZS', 'NY.GNP.PCAP.KD', 'SP.POP.DPND.YG', 'EN.POP.DNST', 'NV.IND.TOTL.KD.ZG', 'SP.POP.DPND.OL', 'NY.GNP.PCAP.KN', 'AG.LND.CREL.HA', 'AG.LND.AGRI.K2', 'AG.YLD.CREL.KG', 'AG.PRD.CREL.MT', 'NV.AGR.TOTL.KN', 'NE.CON.PETC.KD.ZG', 'NE.GDI.TOTL.KD.ZG', 'ER.FSH.AQUA.MT', 'NE.CON.TETC.CN', 'NE.CON.TETC.KN', 'NE.CON.TETC.KD', 'MS.MIL.MPRT.KD', 'NE.CON.TETC.ZS', 'NE.CON.TOTL.CN', 'NE.CON.TOTL.KN', 'NE.CON.TOTL.KD', 'NV.AGR.TOTL.CN', 'NE.CON.GOVT.KD.ZG', 'NV.AGR.TOTL.KD', 'NV.AGR.TOTL.ZS', 'AG.SRF.TOTL.K2', 'AG.PRD.CROP.XD', 'NE.CON.GOVT.KD', 'NE.EXP.GNFS.KD.ZG', 'NE.CON.GOVT.KN', 'NE.CON.GOVT.ZS', 'NE.CON.PRVT.PC.KD.ZG', 'AG.LND.AGRI.ZS', 'NY.GNP.MKTP.KD.ZG', 'EN.URB.LCTY.UR.ZS', 'NE.EXP.GNFS.CN', 'EN.URB.LCTY', 'TM.VAL.MRCH.CD.WT', 'SP.POP.GROW', 'NE.EXP.GNFS.KN', 'NV.IND.TOTL.ZS', 'ER.FSH.CAPT.MT', 'NE.RSB.GNFS.ZS', 'TM.VAL.MRCH.RS.ZS', 'SP.POP.65UP.TO.ZS', 'NE.RSB.GNFS.KN', 'TM.VAL.MRCH.WL.CD', 'SP.POP.1564.TO.ZS', 'EN.URB.MCTY', 'EN.URB.MCTY.TL.ZS', 'SP.RUR.TOTL.ZG', 'SP.RUR.TOTL.ZS', 'NE.EXP.GNFS.ZS', 'SP.RUR.TOTL', 'TX.VAL.MRCH.R1.ZS', 'SP.POP.TOTL', 'SP.POP.TOTL.FE.ZS', 'NE.EXP.GNFS.KD', 'NY.EXP.CAPM.KN', 'TM.VAL.MRCH.HI.ZS', 'SP.DYN.LE00.MA.IN', 'SP.DYN.IMRT.IN', 'DT.ODA.ALLD.KD', 'FP.CPI.TOTL.ZG', 'SH.DYN.MORT', 'DT.ODA.ODAT.PC.ZS', 'DT.ODA.ALLD.CD', 'EN.ATM.CO2E.GF.ZS', 'DC.DAC.USAL.CD', 'DC.DAC.DEUL.CD', 'DC.DAC.TOTL.CD', 'NY.GSR.NFCY.CN', 'NE.RSB.GNFS.CN', 'SP.DYN.AMRT.MA', 'DT.ODA.ODAT.CD', 'SP.POP.0014.TO.ZS', 'NV.IND.TOTL.KD', 'NV.IND.TOTL.KN', 'DT.ODA.ODAT.KD', 'SP.DYN.CBRT.IN', 'SH.DTH.MORT', 'TM.VAL.MRCH.OR.ZS', 'SH.DTH.IMRT', 'NV.IND.TOTL.CN', 'SP.DYN.AMRT.FE', 'TM.VAL.MRCH.R5.ZS', 'NE.IMP.GNFS.CN', 'NY.GDP.DISC.CN', 'NE.DAB.TOTL.CN', 'SP.DYN.TFRT.IN', 'NE.DAB.DEFL.ZS', 'SP.DYN.LE00.IN', 'NE.CON.PRVT.KD', 'NE.DAB.TOTL.KN', 'NE.CON.PRVT.KN', 'NE.CON.PRVT.PC.KD', 'NE.CON.PETC.ZS', 'EN.ATM.CO2E.GF.KT', 'NE.CON.PETC.KD', 'NE.CON.PETC.KN', 'NE.CON.PETC.CN', 'NE.CON.PRVT.CN', 'SP.URB.GROW', 'NE.DAB.TOTL.KD', 'NY.GDS.TOTL.CN', 'NE.DAB.TOTL.ZS', 'BX.GRT.EXTA.CD.WD', 'NE.GDI.TOTL.KD', 'NE.GDI.TOTL.KN', 'NE.GDI.TOTL.CN', 'NY.GDY.TOTL.KN', 'NY.GDS.TOTL.ZS', 'EN.ATM.CO2E.KT', 'NE.GDI.TOTL.ZS', 'TX.VAL.MRCH.RS.ZS', 'SP.URB.TOTL.IN.ZS', 'NV.IND.MANF.KD', 'NV.SRV.TETC.CN', 'FP.CPI.TOTL', 'NE.IMP.GNFS.KD', 'NV.IND.MANF.KN', 'NV.SRV.TETC.KN', 'EN.ATM.CO2E.SF.KT', 'NV.IND.MANF.CN', 'SP.DYN.CDRT.IN', 'TX.VAL.MRCH.CD.WT', 'NY.GDP.DISC.KN', 'NV.SRV.TETC.ZS', 'NE.IMP.GNFS.KN', 'TX.VAL.MRCH.WL.CD', 'NV.SRV.TETC.KD', 'SP.URB.TOTL', 'EN.ATM.CO2E.SF.ZS', 'NV.IND.MANF.ZS', 'SP.DYN.LE00.FE.IN', 'NE.TRD.GNFS.ZS', 'FI.RES.XGLD.CD', 'EN.ATM.CO2E.PC', 'SP.DYN.TO65.FE.ZS', 'FI.RES.TOTL.CD', 'NE.IMP.GNFS.ZS', 'NY.TTF.GNFS.KN', 'BX.GRT.TECH.CD.WD', 'EN.ATM.CO2E.LF.ZS', 'EN.ATM.CO2E.LF.KT', 'SP.DYN.TO65.MA.ZS', 'ER.FSH.PROD.MT', 'AG.LND.ARBL.HA.PC', 'AG.LND.TOTL.K2', 'SP.POP.DPND', 'NY.GNP.PCAP.CN', 'NY.GDP.DEFL.KD.ZG', 'NV.IND.MANF.KD.ZG', 'AG.LND.ARBL.HA', 'NE.IMP.GNFS.KD.ZG', 'DC.DAC.JPNL.CD', 'SP.ADO.TFRT', 'AG.LND.ARBL.ZS', 'AG.PRD.LVSK.XD', 'NV.SRV.TETC.KD.ZG'])

# %%
list_of_indicator_names = list(WDI_design_matrix_df.columns)[1:]

# %%
list_of_indicator_codes = ["Year"]

# %%
for name in list_of_indicator_names:
    list_of_indicator_codes.append( the_dictionary[name] )

# %%
list_of_indicator_codes
# Out:
# ['Year',
#  'EN.ATM.CO2E.KD.GD',
#  'NY.GNP.MKTP.KN',
#  'NY.GNP.MKTP.CN',
#  'NY.GNP.PCAP.KD.ZG',
#  'NY.GNP.MKTP.KD',
#  'NE.CON.GOVT.CN',
#  'DC.DAC.GBRL.CD',
#  'AG.PRD.FOOD.XD',
#  'NE.CON.PRVT.KD.ZG',
#  'AG.LND.CROP.ZS',
#  'NY.GNP.PCAP.KD',
#  'SP.POP.DPND.YG',
#  'EN.POP.DNST',
#  'NV.IND.TOTL.KD.ZG',
#  'SP.POP.DPND.OL',
#  'NY.GNP.PCAP.KN',
#  'AG.LND.CREL.HA',
#  'AG.LND.AGRI.K2',
#  'AG.YLD.CREL.KG',
#  'AG.PRD.CREL.MT',
#  'NV.AGR.TOTL.KN',
#  'NE.CON.PETC.KD.ZG',
#  'NE.GDI.TOTL.KD.ZG',
#  'ER.FSH.AQUA.MT',
#  'NE.CON.TETC.CN',
#  'NE.CON.TETC.KN',
#  'NE.CON.TETC.KD',
#  'MS.MIL.MPRT.KD',
#  'NE.CON.TETC.ZS',
#  'NE.CON.TOTL.CN',
#  'NE.CON.TOTL.KN',
#  'NE.CON.TOTL.KD',
#  'NV.AGR.TOTL.CN',
#  'NE.CON.GOVT.KD.ZG',
#  'NV.AGR.TOTL.KD',
#  'NV.AGR.TOTL.ZS',
#  'AG.SRF.TOTL.K2',
#  'AG.PRD.CROP.XD',
#  'NE.CON.GOVT.KD',
#  'NE.EXP.GNFS.KD.ZG',
#  'NE.CON.GOVT.KN',
#  'NE.CON.GOVT.ZS',
#  'NE.CON.PRVT.PC.KD.ZG',
#  'AG.LND.AGRI.ZS',
#  'NY.GNP.MKTP.KD.ZG',
#  'EN.URB.LCTY.UR.ZS',
#  'NE.EXP.GNFS.CN',
#  'EN.URB.LCTY',
#  'TM.VAL.MRCH.CD.WT',
#  'SP.POP.GROW',
#  'NE.EXP.GNFS.KN',
#  'NV.IND.TOTL.ZS',
#  'ER.FSH.CAPT.MT',
#  'NE.RSB.GNFS.ZS',
#  'TM.VAL.MRCH.RS.ZS',
#  'SP.POP.65UP.TO.ZS',
#  'NE.RSB.GNFS.KN',
#  'TM.VAL.MRCH.WL.CD',
#  'SP.POP.1564.TO.ZS',
#  'EN.URB.MCTY',
#  'EN.URB.MCTY.TL.ZS',
#  'SP.RUR.TOTL.ZG',
#  'SP.RUR.TOTL.ZS',
#  'NE.EXP.GNFS.ZS',
#  'SP.RUR.TOTL',
#  'TX.VAL.MRCH.R1.ZS',
#  'SP.POP.TOTL',
#  'SP.POP.TOTL.FE.ZS',
#  'NE.EXP.GNFS.KD',
#  'NY.EXP.CAPM.KN',
#  'TM.VAL.MRCH.HI.ZS',
#  'SP.DYN.LE00.MA.IN',
#  'SP.DYN.IMRT.IN',
#  'DT.ODA.ALLD.KD',
#  'FP.CPI.TOTL.ZG',
#  'SH.DYN.MORT',
#  'DT.ODA.ODAT.PC.ZS',
#  'DT.ODA.ALLD.CD',
#  'EN.ATM.CO2E.GF.ZS',
#  'DC.DAC.USAL.CD',
#  'DC.DAC.DEUL.CD',
#  'DC.DAC.TOTL.CD',
#  'NY.GSR.NFCY.CN',
#  'NE.RSB.GNFS.CN',
#  'SP.DYN.AMRT.MA',
#  'DT.ODA.ODAT.CD',
#  'SP.POP.0014.TO.ZS',
#  'NV.IND.TOTL.KD',
#  'NV.IND.TOTL.KN',
#  'DT.ODA.ODAT.KD',
#  'SP.DYN.CBRT.IN',
#  'SH.DTH.MORT',
#  'TM.VAL.MRCH.OR.ZS',
#  'SH.DTH.IMRT',
#  'NV.IND.TOTL.CN',
#  'SP.DYN.AMRT.FE',
#  'TM.VAL.MRCH.R5.ZS',
#  'NE.IMP.GNFS.CN',
#  'NY.GDP.DISC.CN',
#  'NE.DAB.TOTL.CN',
#  'SP.DYN.TFRT.IN',
#  'NE.DAB.DEFL.ZS',
#  'SP.DYN.LE00.IN',
#  'NE.CON.PRVT.KD',
#  'NE.DAB.TOTL.KN',
#  'NE.CON.PRVT.KN',
#  'NE.CON.PRVT.PC.KD',
#  'NE.CON.PETC.ZS',
#  'EN.ATM.CO2E.GF.KT',
#  'NE.CON.PETC.KD',
#  'NE.CON.PETC.KN',
#  'NE.CON.PETC.CN',
#  'NE.CON.PRVT.CN',
#  'SP.URB.GROW',
#  'NE.DAB.TOTL.KD',
#  'NY.GDS.TOTL.CN',
#  'NE.DAB.TOTL.ZS',
#  'BX.GRT.EXTA.CD.WD',
#  'NE.GDI.TOTL.KD',
#  'NE.GDI.TOTL.KN',
#  'NE.GDI.TOTL.CN',
#  'NY.GDY.TOTL.KN',
#  'NY.GDS.TOTL.ZS',
#  'EN.ATM.CO2E.KT',
#  'NE.GDI.TOTL.ZS',
#  'TX.VAL.MRCH.RS.ZS',
#  'SP.URB.TOTL.IN.ZS',
#  'NV.IND.MANF.KD',
#  'NV.SRV.TETC.CN',
#  'FP.CPI.TOTL',
#  'NE.IMP.GNFS.KD',
#  'NV.IND.MANF.KN',
#  'NV.SRV.TETC.KN',
#  'EN.ATM.CO2E.SF.KT',
#  'NV.IND.MANF.CN',
#  'SP.DYN.CDRT.IN',
#  'TX.VAL.MRCH.CD.WT',
#  'NY.GDP.DISC.KN',
#  'NV.SRV.TETC.ZS',
#  'NE.IMP.GNFS.KN',
#  'TX.VAL.MRCH.WL.CD',
#  'NV.SRV.TETC.KD',
#  'SP.URB.TOTL',
#  'EN.ATM.CO2E.SF.ZS',
#  'NV.IND.MANF.ZS',
#  'SP.DYN.LE00.FE.IN',
#  'NE.TRD.GNFS.ZS',
#  'FI.RES.XGLD.CD',
#  'EN.ATM.CO2E.PC',
#  'SP.DYN.TO65.FE.ZS',
#  'FI.RES.TOTL.CD',
#  'NE.IMP.GNFS.ZS',
#  'NY.TTF.GNFS.KN',
#  'BX.GRT.TECH.CD.WD',
#  'EN.ATM.CO2E.LF.ZS',
#  'EN.ATM.CO2E.LF.KT',
#  'SP.DYN.TO65.MA.ZS',
#  'ER.FSH.PROD.MT',
#  'AG.LND.ARBL.HA.PC',
#  'AG.LND.TOTL.K2',
#  'SP.POP.DPND',
#  'NY.GNP.PCAP.CN',
#  'NY.GDP.DEFL.KD.ZG',
#  'NV.IND.MANF.KD.ZG',
#  'AG.LND.ARBL.HA',
#  'NE.IMP.GNFS.KD.ZG',
#  'DC.DAC.JPNL.CD',
#  'SP.ADO.TFRT',
#  'AG.LND.ARBL.ZS',
#  'AG.PRD.LVSK.XD',
#  'NV.SRV.TETC.KD.ZG']

# %%
WDI_design_matrix_df.columns = list_of_indicator_codes

# %%
WDI_design_matrix_df_by_year = WDI_design_matrix_df.set_index("Year")

# %%
WDI_design_matrix_df_by_year.to_csv(WDI_path+"completed_values_1962_2013_design_matrix_with_codes_by_year.csv")

# %% [markdown]
# ### Constructing a Dictionary for Y

# %%
WDI_design_matrix_Y_df = pd.read_csv(WDI_path+"complete_values_Y_1962_2013_design_matrix.csv")

# %%
list_of_Y_indicator_names = list(WDI_design_matrix_Y_df.columns)[1:]

# %%
list_of_Y_indicator_names
# Out:
# ['GDP (constant LCU)',
#  'GDP growth (annual %)',
#  'GDP per capita growth (annual %)',
#  'GDP per capita (constant 2010 US$)',
#  'GDP at market prices (constant 2010 US$)',
#  'GDP per capita (constant LCU)',
#  'GDP deflator (base year varies by country)',
#  'GDP (current LCU)',
#  'GDP per capita (current LCU)']

# %%
list_of_Y_indicator_codes = ["Year"]

# %%
counter = 1

# %%
for name in list_of_Y_indicator_names:
    code = "Y"+str(counter)
    list_of_Y_indicator_codes.append(code)
    counter+=1

# %%
list_of_Y_indicator_codes
# Out:
# ['Year', 'Y1', 'Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9']

# %%
WDI_design_matrix_Y_df.columns = list_of_Y_indicator_codes

# %%
WDI_design_matrix_Y_df_by_year = WDI_design_matrix_Y_df.set_index("Year")

# %%
WDI_design_matrix_Y_df_by_year.to_csv(WDI_path+"completed_values_Y_1962_2013_design_matrix_with_codes_by_year.csv")

# %% [markdown]
# These are examples from [Time Series Forecasting Methods](https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/).
# Please use the `wdi-project` conda virtual environment.

# %%
import csv
import pandas as pd
import numpy as np
import pickle

# %%
# contrived dataset
data = [ x + random() for x in range(1,100) ]

# %%
data[98]
# Out:
# 99.56526230271257

# %%
# fit model
model = AR(data)

# %%
model_fit = model.fit()

# %%
# make prediction
yhat = model_fit.predict(len(data), len(data)+1)

# %%
print(yhat)
# Out:
# [100.39176043 101.42197356]

# %% [markdown]
# The WDI path is shown below.

# %%
WDI_path="/home/hendra/Datasets/WDI_Indonesia/"
